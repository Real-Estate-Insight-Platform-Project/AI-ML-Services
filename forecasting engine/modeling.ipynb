# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data\State_lagged.csv")

# %%
df
# Out:
#         state state_id month_date_yyyymm  median_listing_price  \
# 0      Alaska       AK        2017-08-01                279000
# 1      Alaska       AK        2017-09-01                275000
# 2      Alaska       AK        2017-10-01                274900
# 3      Alaska       AK        2017-11-01                269900
# 4      Alaska       AK        2017-12-01                267950
# ...       ...      ...               ...                   ...
# 4840  Wyoming       WY        2025-02-01                459725
# 4841  Wyoming       WY        2025-03-01                459900
# 4842  Wyoming       WY        2025-04-01                476000
# 4843  Wyoming       WY        2025-05-01                495000
# 4844  Wyoming       WY        2025-06-01                496741
#
#       median_listing_price_prev  median_listing_price_mm_prev  \
# 0                      279375.0                     -0.006667
# 1                      279000.0                     -0.001342
# ...
