# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# country_df = pd.read_csv("data\Country.csv")
# country_history_df = pd.read_csv("data\Country_History.csv")
county_df = pd.read_csv("data\County.csv")
county_history_df = pd.read_csv("data\County_History.csv")
# metro_df = pd.read_csv("data\Metro.csv")
# metro_history_df = pd.read_csv("data\Metro_History.csv")
state_df = pd.read_csv("data\State.csv")
state_history_df = pd.read_csv("data\State_History.csv")
# zip_df = pd.read_csv("data\Zip.csv")
# zip_history_df = pd.read_csv("data\Zip_History.csv")

# %%
county_history_df
# Out:
#         month_date_yyyymm  county_fips     county_name  median_listing_price  \
# 0                  202506        45079    richland, sc              289900.0
# 1                  202506        40085        love, ok              323700.0
# 2                  202506        39057      greene, oh              364000.0
# 3                  202506        19073      greene, ia              176250.0
# 4                  202506        31181     webster, ne              174750.0
# ...                   ...          ...             ...                   ...
# 335188             201607        48233  hutchinson, tx              105900.0
# 335189             201607        37035     catawba, nc              209900.0
# 335190             201607         4015      mohave, az              234900.0
# 335191             201607        37123  montgomery, nc              329000.0
# 335192             201607        12071         lee, fl              305900.0
#
#         median_listing_price_mm  median_listing_price_yy  \
# 0                        0.0000                  -0.0333
# 1                        0.0195                   0.2948
# 2                        0.0400                   0.0196
# 3                       -0.0042                   0.0602
# 4                       -0.1152                   0.2527
# ...                         ...                      ...
# 335188                      NaN                      NaN
# 335189                      NaN                      NaN
# 335190                      NaN                      NaN
# 335191                      NaN                      NaN
# 335192                      NaN                      NaN
#
#         active_listing_count  active_listing_count_mm  \
# 0                     1241.0                   0.0891
# 1                       50.0                   0.3026
# 2                      217.0                  -0.0069
# 3                       34.0                  -0.1410
# 4                       13.0                  -0.0714
# ...                      ...                      ...
# 335188                  79.0                      NaN
# 335189                 887.0                      NaN
# 335190                1606.0                      NaN
# 335191                 255.0                      NaN
# 335192                7386.0                      NaN
#
#         active_listing_count_yy  median_days_on_market  ...  \
# 0                        0.2882                   37.0  ...
# 1                        0.4559                   66.0  ...
# 2                       -0.0378                   36.0  ...
# 3                        0.0806                   68.0  ...
# 4                        0.4444                   42.0  ...
# ...                         ...                    ...  ...
# 335188                      NaN                   61.0  ...
# 335189                      NaN                   73.0  ...
# 335190                      NaN                   83.0  ...
# 335191                      NaN                  109.0  ...
# 335192                      NaN                   85.0  ...
#
#         average_listing_price  average_listing_price_mm  \
# 0                    359136.0                   -0.0120
# 1                    388866.0                   -0.0454
# 2                    402502.0                    0.0319
# 3                    222163.0                   -0.0556
# 4                    353275.0                   -0.0143
# ...                       ...                       ...
# 335188               139006.0                       NaN
# 335189               294663.0                       NaN
# 335190               292296.0                       NaN
# 335191               405866.0                       NaN
# 335192               476566.0                       NaN
#
#         average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                        -0.0324               2289.0                  0.0228
# 1                         0.0871                 56.0                  0.2065
# 2                         0.0041                539.0                 -0.0182
# 3                        -0.0108                 46.0                 -0.1415
# 4                         0.7768                 21.0                  0.0789
# ...                          ...                  ...                     ...
# 335188                       NaN                121.0                     NaN
# 335189                       NaN                948.0                     NaN
# 335190                       NaN               1737.0                     NaN
# 335191                       NaN                279.0                     NaN
# 335192                       NaN              10449.0                     NaN
#
#         total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                       0.1708         0.8460           -0.1189
# 1                       0.3875         0.1414           -0.0691
# 2                      -0.0037         1.4896           -0.0379
# 3                       0.1375         0.3582           -0.0008
# 4                       0.4643         0.5769            0.2198
# ...                        ...            ...               ...
# 335188                     NaN         0.5316               NaN
# 335189                     NaN         0.0981               NaN
# 335190                     NaN         0.0834               NaN
# 335191                     NaN         0.0902               NaN
# 335192                     NaN         0.4157               NaN
#
#         pending_ratio_yy  quality_flag
# 0                -0.2090           0.0
# 1                -0.0351           0.0
# 2                 0.1118           0.0
# 3                 0.0679           0.0
# 4                 0.0214           0.0
# ...                  ...           ...
# 335188               NaN           NaN
# 335189               NaN           NaN
# 335190               NaN           NaN
# 335191               NaN           NaN
# 335192               NaN           NaN
#
# [335193 rows x 46 columns]

# %%
state_history_df
# Out:
#       month_date_yyyymm          state state_id  median_listing_price  \
# 0                202506       Kentucky       KY                315000
# 1                202506  West Virginia       WV                275000
# 2                202506          Idaho       ID                599000
# 3                202506          Texas       TX                378000
# 4                202506       Virginia       VA                473914
# ...                 ...            ...      ...                   ...
# 5503             201607         Kansas       KS                159000
# 5504             201607         Oregon       OR                359000
# 5505             201607        Georgia       GA                234900
# 5506             201607     New Jersey       NJ                312000
# 5507             201607       Illinois       IL                224900
#
#       median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                      0.0003                   0.0000                 10693
# 1                      0.0189                   0.1134                  3674
# 2                      0.0052                   0.0328                  9077
# 3                      0.0080                  -0.0052                138255
# 4                     -0.0023                   0.0533                 20273
# ...                       ...                      ...                   ...
# 5503                      NaN                      NaN                 10809
# 5504                      NaN                      NaN                 17213
# 5505                      NaN                      NaN                 61142
# 5506                      NaN                      NaN                 55386
# 5507                      NaN                      NaN                 61100
#
#       active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# 0                      0.0499                   0.3001                     50
# 1                      0.0868                   0.1556                     48
# 2                      0.1366                   0.2009                     46
# 3                      0.0490                   0.2706                     56
# 4                      0.0409                   0.4013                     39
# ...                       ...                      ...                    ...
# 5503                      NaN                      NaN                     60
# 5504                      NaN                      NaN                     47
# 5505                      NaN                      NaN                     65
# 5506                      NaN                      NaN                     71
# 5507                      NaN                      NaN                     58
#
#       ...  average_listing_price  average_listing_price_mm  \
# 0     ...                 398834                    0.0035
# 1     ...                 344764                    0.0138
# 2     ...                 924644                    0.0260
# 3     ...                 539255                   -0.0019
# 4     ...                 663074                   -0.0147
# ...   ...                    ...                       ...
# 5503  ...                 237786                       NaN
# 5504  ...                 480480                       NaN
# 5505  ...                 346839                       NaN
# 5506  ...                 476833                       NaN
# 5507  ...                 349042                       NaN
#
#       average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                       0.0043                17401                  0.0367
# 1                       0.0448                 6224                  0.0410
# 2                       0.0258                13293                  0.0820
# 3                      -0.0136               179455                  0.0276
# 4                       0.0021                32017                  0.0159
# ...                        ...                  ...                     ...
# 5503                       NaN                12311                     NaN
# 5504                       NaN                19018                     NaN
# 5505                       NaN                76778                     NaN
# 5506                       NaN                62017                     NaN
# 5507                       NaN                90015                     NaN
#
#       total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                     0.2047         0.6276           -0.0243
# 1                     0.0700         0.6963           -0.0685
# 2                     0.1389         0.4664           -0.0648
# 3                     0.2064         0.2995           -0.0269
# 4                     0.2466         0.5839           -0.0374
# ...                      ...            ...               ...
# 5503                     NaN         0.1381               NaN
# 5504                     NaN         0.1075               NaN
# 5505                     NaN         0.2693               NaN
# 5506                     NaN         0.1213               NaN
# 5507                     NaN         0.4776               NaN
#
#       pending_ratio_yy  quality_flag
# 0              -0.1211           0.0
# 1              -0.1278           0.0
# 2              -0.0672           0.0
# 3              -0.0696           0.0
# 4              -0.2073           0.0
# ...                ...           ...
# 5503               NaN           NaN
# 5504               NaN           NaN
# 5505               NaN           NaN
# 5506               NaN           NaN
# 5507               NaN           NaN
#
# [5508 rows x 46 columns]

# %%
state_history_df['month_date_yyyymm'] = pd.to_datetime(state_history_df['month_date_yyyymm'].astype(str), format='%Y%m')

# %%
state_history_df
# Out:
#      month_date_yyyymm          state state_id  median_listing_price  \
# 0           2025-06-01       Kentucky       KY                315000
# 1           2025-06-01  West Virginia       WV                275000
# 2           2025-06-01          Idaho       ID                599000
# 3           2025-06-01          Texas       TX                378000
# 4           2025-06-01       Virginia       VA                473914
# ...                ...            ...      ...                   ...
# 5503        2016-07-01         Kansas       KS                159000
# 5504        2016-07-01         Oregon       OR                359000
# 5505        2016-07-01        Georgia       GA                234900
# 5506        2016-07-01     New Jersey       NJ                312000
# 5507        2016-07-01       Illinois       IL                224900
#
#       median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0                      0.0003                   0.0000                 10693
# 1                      0.0189                   0.1134                  3674
# 2                      0.0052                   0.0328                  9077
# 3                      0.0080                  -0.0052                138255
# 4                     -0.0023                   0.0533                 20273
# ...                       ...                      ...                   ...
# 5503                      NaN                      NaN                 10809
# 5504                      NaN                      NaN                 17213
# 5505                      NaN                      NaN                 61142
# 5506                      NaN                      NaN                 55386
# 5507                      NaN                      NaN                 61100
#
#       active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# 0                      0.0499                   0.3001                     50
# 1                      0.0868                   0.1556                     48
# 2                      0.1366                   0.2009                     46
# 3                      0.0490                   0.2706                     56
# 4                      0.0409                   0.4013                     39
# ...                       ...                      ...                    ...
# 5503                      NaN                      NaN                     60
# 5504                      NaN                      NaN                     47
# 5505                      NaN                      NaN                     65
# 5506                      NaN                      NaN                     71
# 5507                      NaN                      NaN                     58
#
#       ...  average_listing_price  average_listing_price_mm  \
# 0     ...                 398834                    0.0035
# 1     ...                 344764                    0.0138
# 2     ...                 924644                    0.0260
# 3     ...                 539255                   -0.0019
# 4     ...                 663074                   -0.0147
# ...   ...                    ...                       ...
# 5503  ...                 237786                       NaN
# 5504  ...                 480480                       NaN
# 5505  ...                 346839                       NaN
# 5506  ...                 476833                       NaN
# 5507  ...                 349042                       NaN
#
#       average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                       0.0043                17401                  0.0367
# 1                       0.0448                 6224                  0.0410
# 2                       0.0258                13293                  0.0820
# 3                      -0.0136               179455                  0.0276
# 4                       0.0021                32017                  0.0159
# ...                        ...                  ...                     ...
# 5503                       NaN                12311                     NaN
# 5504                       NaN                19018                     NaN
# 5505                       NaN                76778                     NaN
# 5506                       NaN                62017                     NaN
# 5507                       NaN                90015                     NaN
#
#       total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                     0.2047         0.6276           -0.0243
# 1                     0.0700         0.6963           -0.0685
# 2                     0.1389         0.4664           -0.0648
# 3                     0.2064         0.2995           -0.0269
# 4                     0.2466         0.5839           -0.0374
# ...                      ...            ...               ...
# 5503                     NaN         0.1381               NaN
# 5504                     NaN         0.1075               NaN
# 5505                     NaN         0.2693               NaN
# 5506                     NaN         0.1213               NaN
# 5507                     NaN         0.4776               NaN
#
#       pending_ratio_yy  quality_flag
# 0              -0.1211           0.0
# 1              -0.1278           0.0
# 2              -0.0672           0.0
# 3              -0.0696           0.0
# 4              -0.2073           0.0
# ...                ...           ...
# 5503               NaN           NaN
# 5504               NaN           NaN
# 5505               NaN           NaN
# 5506               NaN           NaN
# 5507               NaN           NaN
#
# [5508 rows x 46 columns]

# %%
def customDescription(df: pd.DataFrame, numeric_only: bool = False):
    if numeric_only:
        df = df.select_dtypes(include=np.number)
    
    desc = pd.DataFrame(index=df.columns.to_list())
    desc['type'] = df.dtypes
    desc['count'] = df.count()
    desc['nunique'] = df.nunique()
    desc['null'] = df.isnull().sum()
    
    # Calculate mode and handle multiple modes
    modes = df.mode()
    desc['mode'] = np.nan  # Default to NaN
    for col in df.columns:
        if len(modes[col].dropna()) == 1:  # Single mode exists
            desc.loc[col, 'mode'] = modes[col].iloc[0]
        else:  # Multiple modes
            desc.loc[col, 'mode'] = np.nan

    # Calculate least frequent value
    desc['least_frequent'] = np.nan  # Default to NaN
    for col in df.columns:
        value_counts = df[col].value_counts(dropna=False)
        if not value_counts.empty:
            least_freq_count = value_counts.min()  # Find the minimum frequency
            least_freq_values = value_counts[value_counts == least_freq_count].index
            
            if len(least_freq_values) == 1:  # If exactly one least frequent value exists
                desc.loc[col, 'least_frequent'] = least_freq_values[0]
            else:  # Multiple least frequent values
                desc.loc[col, 'least_frequent'] = np.nan
    
    # Handle numeric columns
    numeric_cols = df.select_dtypes(include=np.number)
    if not numeric_cols.empty:
        numeric_desc = numeric_cols.describe().T.drop(columns=['count', 'std', '25%', '50%', '75%'], axis=1)
        for col in numeric_cols.columns:
            desc.loc[col, 'mean'] = numeric_desc.loc[col, 'mean']
            desc.loc[col, 'min'] = numeric_desc.loc[col, 'min']
            desc.loc[col, 'max'] = numeric_desc.loc[col, 'max']
    
    # Handle datetime columns
    datetime_cols = df.select_dtypes(include=['datetime64[ns]', 'datetime64[ns, UTC]'])
    for col in datetime_cols.columns:
        desc.loc[col, 'min'] = df[col].min()
        desc.loc[col, 'max'] = df[col].max()
    
    return desc

# %%
df = state_history_df.copy()

# %%
customDescription(df)
# Out:
#                                                    type  count  nunique  null  \
# month_date_yyyymm                        datetime64[ns]   5508      108     0
# state                                            object   5508       51     0
# state_id                                         object   5508       51     0
# median_listing_price                              int64   5508     2617     0
# median_listing_price_mm                         float64   4896     1001   612
# median_listing_price_yy                         float64   4896     2151   612
# active_listing_count                              int64   5508     5034     0
# active_listing_count_mm                         float64   4896     2469   612
# active_listing_count_yy                         float64   4896     3822   612
# median_days_on_market                             int64   5508      130     0
# median_days_on_market_mm                        float64   4896     2169   612
# median_days_on_market_yy                        float64   4896     2508   612
# new_listing_count                                 int64   5508     3840     0
# new_listing_count_mm                            float64   4896     3400   612
# new_listing_count_yy                            float64   4896     3006   612
# price_increased_count                             int64   5508     1084     0
# price_increased_count_mm                        float64   4892     2786   616
# price_increased_count_yy                        float64   4894     3217   614
# price_increased_share                           float64   5508      581     0
# price_increased_share_mm                        float64   4896      364   612
# price_increased_share_yy                        float64   4896      642   612
# price_reduced_count                               int64   5508     3200     0
# price_reduced_count_mm                          float64   4896     3552   612
# price_reduced_count_yy                          float64   4896     4064   612
# price_reduced_share                             float64   5508     1909     0
# price_reduced_share_mm                          float64   4896     1010   612
# price_reduced_share_yy                          float64   4896     1594   612
# pending_listing_count                           float64   5481     4612    27
# pending_listing_count_mm                        float64   4871     2898   637
# pending_listing_count_yy                        float64   4860     3786   648
# median_listing_price_per_square_foot              int64   5508      478     0
# median_listing_price_per_square_foot_mm         float64   4896      730   612
# median_listing_price_per_square_foot_yy         float64   4896     2066   612
# median_square_feet                                int64   5508     1059     0
# median_square_feet_mm                           float64   4896      634   612
# median_square_feet_yy                           float64   4896     1524   612
# average_listing_price                             int64   5508     5488     0
# average_listing_price_mm                        float64   4896     1042   612
# average_listing_price_yy                        float64   4896     2314   612
# total_listing_count                               int64   5508     5173     0
# total_listing_count_mm                          float64   4896     2350   612
# total_listing_count_yy                          float64   4896     3398   612
# pending_ratio                                   float64   5481     4443    27
# pending_ratio_mm                                float64   4871     2272   637
# pending_ratio_yy                                float64   4861     3648   647
# quality_flag                                    float64   4896        2   612
#
#                                                 mode  least_frequent  \
# month_date_yyyymm                                NaN             NaN
# state                                            NaN             NaN
# state_id                                         NaN             NaN
# median_listing_price                     299900.0000             NaN
# median_listing_price_mm                       0.0000             NaN
# median_listing_price_yy                       0.0000             NaN
# active_listing_count                             NaN             NaN
# active_listing_count_mm                          NaN             NaN
# active_listing_count_yy                          NaN             NaN
# median_days_on_market                        51.0000             NaN
# median_days_on_market_mm                      0.0000             NaN
# median_days_on_market_yy                      0.0000             NaN
# new_listing_count                                NaN             NaN
# new_listing_count_mm                             NaN             NaN
# new_listing_count_yy                          0.0000             NaN
# price_increased_count                        20.0000             NaN
# price_increased_count_mm                      0.0000             NaN
# price_increased_count_yy                      0.0000             NaN
# price_increased_share                         0.0055             NaN
# price_increased_share_mm                     -0.0003             NaN
# price_increased_share_yy                     -0.0009             NaN
# price_reduced_count                         580.0000             NaN
# price_reduced_count_mm                        0.0000             NaN
# price_reduced_count_yy                        0.0000             NaN
# price_reduced_share                              NaN             NaN
# price_reduced_share_mm                        0.0007             NaN
# price_reduced_share_yy                           NaN             NaN
# pending_listing_count                            NaN             NaN
# pending_listing_count_mm                         NaN             NaN
# pending_listing_count_yy                         NaN             NaN
# median_listing_price_per_square_foot        117.0000             NaN
# median_listing_price_per_square_foot_mm       0.0027             NaN
# median_listing_price_per_square_foot_yy       0.0655             NaN
# median_square_feet                         2000.0000             NaN
# median_square_feet_mm                         0.0000             NaN
# median_square_feet_yy                         0.0000             NaN
# average_listing_price                            NaN             NaN
# average_listing_price_mm                      0.0006             NaN
# average_listing_price_yy                      0.0529             NaN
# total_listing_count                              NaN             NaN
# total_listing_count_mm                           NaN             NaN
# total_listing_count_yy                           NaN             NaN
# pending_ratio                                    NaN             NaN
# pending_ratio_mm                                 NaN             NaN
# pending_ratio_yy                                 NaN             NaN
# quality_flag                                  0.0000             1.0
#
#                                                   mean                  min  \
# month_date_yyyymm                                  NaN  2016-07-01 00:00:00
# state                                              NaN                  NaN
# state_id                                           NaN                  NaN
# median_listing_price                     360216.386892             129913.0
# median_listing_price_mm                       0.005309              -0.1038
# median_listing_price_yy                       0.068814              -0.2071
# active_listing_count                      17650.938453                720.0
# active_listing_count_mm                       0.000232              -0.3074
# active_listing_count_yy                      -0.012367              -0.7173
# median_days_on_market                        58.554103                 13.0
# median_days_on_market_mm                      0.008575              -0.6023
# median_days_on_market_yy                     -0.006308              -0.7155
# new_listing_count                          8207.112564                290.0
# new_listing_count_mm                          0.015546              -0.6912
# new_listing_count_yy                         -0.013270              -0.7398
# price_increased_count                       599.119463                  0.0
# price_increased_count_mm                      0.063016                 -1.0
# price_increased_count_yy                      0.144082                 -1.0
# price_increased_share                         0.014464                  0.0
# price_increased_share_mm                     -0.000098              -0.0702
# price_increased_share_yy                     -0.000509              -0.1175
# price_reduced_count                        5142.209150                 72.0
# price_reduced_count_mm                        0.026358              -0.7625
# price_reduced_count_yy                        0.076649              -0.8464
# price_reduced_share                           0.132805               0.0254
# price_reduced_share_mm                        0.000254              -0.1286
# price_reduced_share_yy                        0.002088              -0.2464
# pending_listing_count                      8550.248312                  0.0
# pending_listing_count_mm                      0.024072              -0.9734
# pending_listing_count_yy                      0.228948              -0.9777
# median_listing_price_per_square_foot        195.895062                 79.0
# median_listing_price_per_square_foot_mm       0.005804              -0.1165
# median_listing_price_per_square_foot_yy       0.075114               -0.095
# median_square_feet                         1908.460784                987.0
# median_square_feet_mm                        -0.000336               -0.101
# median_square_feet_yy                        -0.003240              -0.3058
# average_listing_price                    568693.404139             206417.0
# average_listing_price_mm                      0.005413              -0.4512
# average_listing_price_yy                      0.066544              -0.3896
# total_listing_count                       26086.285403                803.0
# total_listing_count_mm                        0.001265              -0.3592
# total_listing_count_yy                       -0.019375              -0.4954
# pending_ratio                                 0.578411                  0.0
# pending_ratio_mm                              0.002429              -0.8669
# pending_ratio_yy                              0.034240              -2.5872
# quality_flag                                  0.024306                  0.0
#
#                                                          max
# month_date_yyyymm                        2025-06-01 00:00:00
# state                                                    NaN
# state_id                                                 NaN
# median_listing_price                                886500.0
# median_listing_price_mm                               0.1135
# median_listing_price_yy                               0.4101
# active_listing_count                                182589.0
# active_listing_count_mm                               0.6116
# active_listing_count_yy                               2.3532
# median_days_on_market                                  157.0
# median_days_on_market_mm                              0.5873
# median_days_on_market_yy                              1.6271
# new_listing_count                                    53332.0
# new_listing_count_mm                                  2.2457
# new_listing_count_yy                                  2.0644
# price_increased_count                                 9466.0
# price_increased_count_mm                                63.0
# price_increased_count_yy                                57.0
# price_increased_share                                 0.1302
# price_increased_share_mm                              0.1023
# price_increased_share_yy                              0.1029
# price_reduced_count                                  71888.0
# price_reduced_count_mm                                2.9498
# price_reduced_count_yy                                5.7706
# price_reduced_share                                   0.4089
# price_reduced_share_mm                                0.1132
# price_reduced_share_yy                                0.3025
# pending_listing_count                                82071.0
# pending_listing_count_mm                             15.9403
# pending_listing_count_yy                             16.1045
# median_listing_price_per_square_foot                   737.0
# median_listing_price_per_square_foot_mm               0.1178
# median_listing_price_per_square_foot_yy               0.4914
# median_square_feet                                    2798.0
# median_square_feet_mm                                 0.1784
# median_square_feet_yy                                 0.2676
# average_listing_price                              1730505.0
# average_listing_price_mm                              0.9244
# average_listing_price_yy                              1.0508
# total_listing_count                                 231347.0
# total_listing_count_mm                                0.7739
# total_listing_count_yy                                1.1688
# pending_ratio                                          3.212
# pending_ratio_mm                                      1.1954
# pending_ratio_yy                                      2.5949
# quality_flag                                             1.0

# %%
pd.set_option('display.max_columns', None)

# %%
df[df['state_id'] == 'WV']
# Out:
#      month_date_yyyymm          state state_id  median_listing_price  \
# 1           2025-06-01  West Virginia       WV                275000
# 75          2025-05-01  West Virginia       WV                269900
# 121         2025-04-01  West Virginia       WV                263881
# 156         2025-03-01  West Virginia       WV                259000
# 243         2025-02-01  West Virginia       WV                247000
# ...                ...            ...      ...                   ...
# 5271        2016-11-01  West Virginia       WV                155925
# 5318        2016-10-01  West Virginia       WV                159000
# 5380        2016-09-01  West Virginia       WV                159875
# 5426        2016-08-01  West Virginia       WV                161350
# 5488        2016-07-01  West Virginia       WV                164900
#
#       median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 1                      0.0189                   0.1134                  3674
# 75                     0.0228                   0.1251                  3380
# 121                    0.0188                   0.0995                  3065
# 156                    0.0486                   0.0837                  2920
# 243                   -0.0006                   0.0706                  3030
# ...                       ...                      ...                   ...
# 5271                      NaN                      NaN                  9084
# 5318                      NaN                      NaN                  9442
# 5380                      NaN                      NaN                  9606
# 5426                      NaN                      NaN                  9591
# 5488                      NaN                      NaN                  9571
#
#       active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# 1                      0.0868                   0.1556                     48
# 75                     0.1030                   0.1558                     45
# 121                    0.0495                   0.0808                     47
# 156                   -0.0363                   0.0607                     65
# 243                   -0.0814                   0.0966                     79
# ...                       ...                      ...                    ...
# 5271                      NaN                      NaN                     95
# 5318                      NaN                      NaN                     90
# 5380                      NaN                      NaN                     87
# 5426                      NaN                      NaN                     82
# 5488                      NaN                      NaN                     79
#
#       median_days_on_market_mm  median_days_on_market_yy  new_listing_count  \
# 1                       0.0556                   -0.0306               1906
# 75                     -0.0323                   -0.0426               1868
# 121                    -0.2846                   -0.0792               1864
# 156                    -0.1772                    0.1017               1584
# 243                     0.0064                    0.0533               1144
# ...                        ...                       ...                ...
# 5271                       NaN                       NaN               1556
# 5318                       NaN                       NaN               1848
# 5380                       NaN                       NaN               1734
# 5426                       NaN                       NaN               2046
# 5488                       NaN                       NaN               1988
#
#       new_listing_count_mm  new_listing_count_yy  price_increased_count  \
# 1                   0.0203                0.0732                     52
# 75                  0.0021                0.0950                     64
# 121                 0.1768                0.0664                     52
# 156                 0.3846               -0.0594                     96
# 243                 0.1064               -0.1513                     84
# ...                    ...                   ...                    ...
# 5271                   NaN                   NaN                     46
# 5318                   NaN                   NaN                     64
# 5380                   NaN                   NaN                     64
# 5426                   NaN                   NaN                     70
# 5488                   NaN                   NaN                     56
#
#       price_increased_count_mm  price_increased_count_yy  \
# 1                      -0.1875                   -0.4348
# 75                      0.2308                    0.0667
# 121                    -0.4583                   -0.5873
# 156                     0.1429                    0.0000
# 243                    -0.1600                   -0.1064
# ...                        ...                       ...
# 5271                       NaN                       NaN
# 5318                       NaN                       NaN
# 5380                       NaN                       NaN
# 5426                       NaN                       NaN
# 5488                       NaN                       NaN
#
#       price_increased_share  price_increased_share_mm  \
# 1                    0.0065                   -0.0017
# 75                   0.0082                    0.0011
# 121                  0.0070                   -0.0075
# 156                  0.0146                    0.0002
# 243                  0.0143                   -0.0022
# ...                     ...                       ...
# 5271                 0.0039                       NaN
# 5318                 0.0054                       NaN
# 5380                 0.0050                       NaN
# 5426                 0.0054                       NaN
# 5488                 0.0042                       NaN
#
#       price_increased_share_yy  price_reduced_count  price_reduced_count_mm  \
# 1                      -0.0053                 1228                  0.1164
# 75                      0.0001                 1100                  0.2443
# 121                    -0.0112                  884                  0.1818
# 156                     0.0003                  748                  0.1000
# 243                    -0.0016                  680                  0.0658
# ...                        ...                  ...                     ...
# 5271                       NaN                 1266                     NaN
# 5318                       NaN                 1532                     NaN
# 5380                       NaN                 1666                     NaN
# 5426                       NaN                 1780                     NaN
# 5488                       NaN                 1724                     NaN
#
#       price_reduced_count_yy  price_reduced_share  price_reduced_share_mm  \
# 1                     0.2429               0.1529                  0.0138
# 75                    0.3189               0.1392                  0.0203
# 121                   0.0351               0.1188                  0.0017
# 156                   0.0054               0.1171                  0.0068
# 243                   0.0366               0.1103                  0.0058
# ...                      ...                  ...                     ...
# 5271                     NaN               0.1082                     NaN
# 5318                     NaN               0.1235                     NaN
# 5380                     NaN               0.1317                     NaN
# 5426                     NaN               0.1378                     NaN
# 5488                     NaN               0.1330                     NaN
#
#       price_reduced_share_yy  pending_listing_count  pending_listing_count_mm  \
# 1                     0.0229                 2558.0                   -0.0104
# 75                    0.0259                 2585.0                    0.0459
# 121                  -0.0008                 2472.0                    0.1780
# 156                   0.0023                 2098.0                    0.1180
# 243                   0.0020                 1877.0                    0.0717
# ...                      ...                    ...                       ...
# 5271                     NaN                 1081.0                       NaN
# 5318                     NaN                 1212.0                       NaN
# 5380                     NaN                 1225.0                       NaN
# 5426                     NaN                 1291.0                       NaN
# 5488                     NaN                 1260.0                       NaN
#
#       pending_listing_count_yy  median_listing_price_per_square_foot  \
# 1                      -0.0237                                   148
# 75                     -0.0458                                   147
# 121                    -0.0104                                   145
# 156                    -0.0446                                   144
# 243                    -0.0511                                   140
# ...                        ...                                   ...
# 5271                       NaN                                    89
# 5318                       NaN                                    90
# 5380                       NaN                                    90
# 5426                       NaN                                    90
# 5488                       NaN                                    91
#
#       median_listing_price_per_square_foot_mm  \
# 1                                      0.0104
# 75                                     0.0133
# 121                                    0.0082
# 156                                    0.0271
# 243                                    0.0098
# ...                                       ...
# 5271                                      NaN
# 5318                                      NaN
# 5380                                      NaN
# 5426                                      NaN
# 5488                                      NaN
#
#       median_listing_price_per_square_foot_yy  median_square_feet  \
# 1                                      0.0888                1803
# 75                                     0.0985                1792
# 121                                    0.0870                1766
# 156                                    0.1150                1754
# 243                                    0.1090                1717
# ...                                       ...                 ...
# 5271                                      NaN                1760
# 5318                                      NaN                1764
# 5380                                      NaN                1773
# 5426                                      NaN                1781
# 5488                                      NaN                1787
#
#       median_square_feet_mm  median_square_feet_yy  average_listing_price  \
# 1                    0.0059                 0.0207                 344764
# 75                   0.0150                 0.0175                 340074
# 121                  0.0066                 0.0193                 331834
# 156                  0.0218                -0.0048                 323062
# 243                 -0.0032                -0.0191                 311327
# ...                     ...                    ...                    ...
# 5271                    NaN                    NaN                 212205
# 5318                    NaN                    NaN                 212698
# 5380                    NaN                    NaN                 213569
# 5426                    NaN                    NaN                 215415
# 5488                    NaN                    NaN                 216063
#
#       average_listing_price_mm  average_listing_price_yy  total_listing_count  \
# 1                       0.0138                    0.0448                 6224
# 75                      0.0248                    0.0342                 5979
# 121                     0.0272                    0.0107                 5527
# 156                     0.0377                   -0.0055                 5010
# 243                     0.0025                   -0.0213                 4925
# ...                        ...                       ...                  ...
# 5271                       NaN                       NaN                10144
# 5318                       NaN                       NaN                10635
# 5380                       NaN                       NaN                10807
# 5426                       NaN                       NaN                10867
# 5488                       NaN                       NaN                10822
#
#       total_listing_count_mm  total_listing_count_yy  pending_ratio  \
# 1                     0.0410                  0.0700         0.6963
# 75                    0.0819                  0.0572         0.7648
# 121                   0.1031                  0.0392         0.8065
# 156                   0.0173                  0.0089         0.7185
# 243                  -0.0166                  0.0407         0.6193
# ...                      ...                     ...            ...
# 5271                     NaN                     NaN         0.1190
# 5318                     NaN                     NaN         0.1284
# 5380                     NaN                     NaN         0.1275
# 5426                     NaN                     NaN         0.1346
# 5488                     NaN                     NaN         0.1316
#
#       pending_ratio_mm  pending_ratio_yy  quality_flag
# 1              -0.0685           -0.1278           0.0
# 75             -0.0417           -0.1615           0.0
# 121             0.0880           -0.0743           0.0
# 156             0.0992           -0.0792           0.0
# 243             0.0885           -0.0964           0.0
# ...                ...               ...           ...
# 5271               NaN               NaN           NaN
# 5318               NaN               NaN           NaN
# 5380               NaN               NaN           NaN
# 5426               NaN               NaN           NaN
# 5488               NaN               NaN           NaN
#
# [108 rows x 46 columns]

# %%
# Sort by state and month
df = df.sort_values(["state_id", "month_date_yyyymm"])

def recompute_mm(df, base_col, mm_col):
    # Compute pct_change
    df[mm_col] = df.groupby("state_id")[base_col].pct_change()
    
    # Replace inf values with the base_col (new month value)
    inf_mask = df[mm_col].replace([np.inf, -np.inf], np.nan).isna() & df[base_col].notna()
    df.loc[inf_mask, mm_col] = df.loc[inf_mask, base_col]

    return df

# %%
# You can loop over all *_mm cols systematically:
base_to_mm = {
    "median_listing_price": "median_listing_price_mm",
    "active_listing_count": "active_listing_count_mm",
    "median_days_on_market": "median_days_on_market_mm",
    "new_listing_count": "new_listing_count_mm",
    "price_increased_count": "price_increased_count_mm",
    "price_increased_share": "price_increased_share_mm",
    "price_reduced_count": "price_reduced_count_mm",
    "price_reduced_share": "price_reduced_share_mm",
    "pending_listing_count": "pending_listing_count_mm",
    "median_listing_price_per_square_foot": "median_listing_price_per_square_foot_mm",
    "median_square_feet": "median_square_feet_mm",
    "average_listing_price": "average_listing_price_mm",
    "total_listing_count": "total_listing_count_mm",
    "pending_ratio": "pending_ratio_mm"
}

for base, mm in base_to_mm.items():
    if base in df.columns and mm in df.columns:
        df = recompute_mm(df, base, mm)

# %%
df.reset_index(drop=True, inplace=True)
df.drop(columns=['quality_flag'], inplace=True, errors='ignore')
df
# Out:
#      month_date_yyyymm    state state_id  median_listing_price  \
# 0           2016-07-01   Alaska       AK                289000
# 1           2016-08-01   Alaska       AK                286375
# 2           2016-09-01   Alaska       AK                284725
# 3           2016-10-01   Alaska       AK                279900
# 4           2016-11-01   Alaska       AK                279700
# ...                ...      ...      ...                   ...
# 5503        2025-02-01  Wyoming       WY                459725
# 5504        2025-03-01  Wyoming       WY                459900
# 5505        2025-04-01  Wyoming       WY                476000
# 5506        2025-05-01  Wyoming       WY                495000
# 5507        2025-06-01  Wyoming       WY                496741
#
#       median_listing_price_mm  median_listing_price_yy  active_listing_count  \
# 0               289000.000000                      NaN                  3784
# 1                   -0.009083                      NaN                  3737
# 2                   -0.005762                      NaN                  3635
# 3                   -0.016946                      NaN                  3297
# 4                   -0.000715                      NaN                  2983
# ...                       ...                      ...                   ...
# 5503                -0.000435                   0.0229                  1834
# 5504                 0.000381                   0.0243                  1826
# 5505                 0.035008                   0.0462                  1945
# 5506                 0.039916                   0.0623                  2208
# 5507                 0.003517                   0.0458                  2519
#
#       active_listing_count_mm  active_listing_count_yy  median_days_on_market  \
# 0                 3784.000000                      NaN                     62
# 1                   -0.012421                      NaN                     68
# 2                   -0.027295                      NaN                     71
# 3                   -0.092985                      NaN                     79
# 4                   -0.095238                      NaN                     87
# ...                       ...                      ...                    ...
# 5503                -0.041797                   0.0956                     88
# 5504                -0.004362                   0.1127                     68
# 5505                 0.065170                   0.1421                     57
# 5506                 0.135219                   0.1820                     51
# 5507                 0.140851                   0.1644                     50
#
#       median_days_on_market_mm  median_days_on_market_yy  new_listing_count  \
# 0                    62.000000                       NaN               1224
# 1                     0.096774                       NaN               1082
# 2                     0.044118                       NaN                898
# 3                     0.112676                       NaN                788
# 4                     0.101266                       NaN                600
# ...                        ...                       ...                ...
# 5503                 -0.011236                   -0.0112                594
# 5504                 -0.227273                   -0.0556                784
# 5505                 -0.161765                   -0.1172                942
# 5506                 -0.105263                    0.0000               1028
# 5507                 -0.019608                    0.0638               1146
#
#       new_listing_count_mm  new_listing_count_yy  price_increased_count  \
# 0              1224.000000                   NaN                     36
# 1                -0.116013                   NaN                     46
# 2                -0.170055                   NaN                     18
# 3                -0.122494                   NaN                     24
# 4                -0.238579                   NaN                     12
# ...                    ...                   ...                    ...
# 5503              0.060714                0.0919                      0
# 5504              0.319865                0.1951                     12
# 5505              0.201531                0.1135                     16
# 5506              0.091295                0.1762                     12
# 5507              0.114786                0.1506                     14
#
#       price_increased_count_mm  price_increased_count_yy  \
# 0                    36.000000                       NaN
# 1                     0.277778                       NaN
# 2                    -0.608696                       NaN
# 3                     0.333333                       NaN
# 4                    -0.500000                       NaN
# ...                        ...                       ...
# 5503                 -1.000000                     -1.00
# 5504                 12.000000                     -0.25
# 5505                  0.333333                     -0.20
# 5506                 -0.250000                      0.00
# 5507                  0.166667                      0.75
#
#       price_increased_share  price_increased_share_mm  \
# 0                    0.0075                  0.007500
# 1                    0.0095                  0.266667
# 2                    0.0040                 -0.578947
# 3                    0.0060                  0.500000
# 4                    0.0035                 -0.416667
# ...                     ...                       ...
# 5503                 0.0000                 -1.000000
# 5504                 0.0041                  0.004100
# 5505                 0.0046                  0.121951
# 5506                 0.0033                 -0.282609
# 5507                 0.0032                 -0.030303
#
#       price_increased_share_yy  price_reduced_count  price_reduced_count_mm  \
# 0                          NaN                 1244             1244.000000
# 1                          NaN                 1262                0.014469
# 2                          NaN                 1134               -0.101426
# 3                          NaN                  896               -0.209877
# 4                          NaN                  646               -0.279018
# ...                        ...                  ...                     ...
# 5503                   -0.0045                  304                0.020134
# 5504                   -0.0018                  332                0.092105
# 5505                   -0.0019                  388                0.168675
# 5506                   -0.0004                  520                0.340206
# 5507                    0.0011                  682                0.311538
#
#       price_reduced_count_yy  price_reduced_share  price_reduced_share_mm  \
# 0                        NaN               0.2416                0.241600
# 1                        NaN               0.2596                0.074503
# 2                        NaN               0.2431               -0.063559
# 3                        NaN               0.2162               -0.110654
# 4                        NaN               0.1778               -0.177613
# ...                      ...                  ...                     ...
# 5503                  0.2459               0.1096                0.047801
# 5504                  0.4310               0.1058               -0.034672
# 5505                  0.2357               0.1135                0.072779
# 5506                  0.3000               0.1354                0.192952
# 5507                  0.2724               0.1597                0.179468
#
#       price_reduced_share_yy  pending_listing_count  pending_listing_count_mm  \
# 0                        NaN                    2.0                  2.000000
# 1                        NaN                    3.0                  0.500000
# 2                        NaN                    4.0                  0.333333
# 3                        NaN                    4.0                  0.000000
# 4                        NaN                    4.0                  0.000000
# ...                      ...                    ...                       ...
# 5503                  0.0180                  435.0                  0.172507
# 5504                  0.0271                  502.0                  0.154023
# 5505                  0.0121                  597.0                  0.189243
# 5506                  0.0166                  615.0                  0.030151
# 5507                  0.0161                  649.0                  0.055285
#
#       pending_listing_count_yy  median_listing_price_per_square_foot  \
# 0                          NaN                                   164
# 1                          NaN                                   164
# 2                          NaN                                   164
# 3                          NaN                                   163
# 4                          NaN                                   163
# ...                        ...                                   ...
# 5503                   -0.0492                                   209
# 5504                   -0.0652                                   208
# 5505                    0.0093                                   209
# 5506                   -0.0144                                   211
# 5507                    0.0973                                   217
#
#       median_listing_price_per_square_foot_mm  \
# 0                                  164.000000
# 1                                    0.000000
# 2                                    0.000000
# 3                                   -0.006098
# 4                                    0.000000
# ...                                       ...
# 5503                                 0.019512
# 5504                                -0.004785
# 5505                                 0.004808
# 5506                                 0.009569
# 5507                                 0.028436
#
#       median_listing_price_per_square_foot_yy  median_square_feet  \
# 0                                         NaN                1800
# 1                                         NaN                1785
# 2                                         NaN                1783
# 3                                         NaN                1764
# 4                                         NaN                1764
# ...                                       ...                 ...
# 5503                                   0.1043                2171
# 5504                                   0.0800                2176
# 5505                                   0.0716                2204
# 5506                                   0.0443                2216
# 5507                                   0.0210                2209
#
#       median_square_feet_mm  median_square_feet_yy  average_listing_price  \
# 0               1800.000000                    NaN                 331337
# 1                 -0.008333                    NaN                 328825
# 2                 -0.001120                    NaN                 326394
# 3                 -0.010656                    NaN                 326889
# 4                  0.000000                    NaN                 328331
# ...                     ...                    ...                    ...
# 5503              -0.014973                -0.0418                1198147
# 5504               0.002303                -0.0357                1166754
# 5505               0.012868                -0.0267                1108065
# 5506               0.005445                -0.0353                1064091
# 5507              -0.003159                -0.0222                1166952
#
#       average_listing_price_mm  average_listing_price_yy  total_listing_count  \
# 0                331337.000000                       NaN                 3784
# 1                    -0.007581                       NaN                 3739
# 2                    -0.007393                       NaN                 3639
# 3                     0.001517                       NaN                 3301
# 4                     0.004411                       NaN                 2986
# ...                        ...                       ...                  ...
# 5503                  0.026985                    0.2415                 2252
# 5504                 -0.026201                    0.2582                 2318
# 5505                 -0.050301                    0.2097                 2535
# 5506                 -0.039685                    0.1772                 2816
# 5507                  0.096666                    0.1760                 3156
#
#       total_listing_count_mm  total_listing_count_yy  pending_ratio  \
# 0                3784.000000                     NaN         0.0005
# 1                  -0.011892                     NaN         0.0007
# 2                  -0.026745                     NaN         0.0011
# 3                  -0.092883                     NaN         0.0012
# 4                  -0.095426                     NaN         0.0012
# ...                      ...                     ...            ...
# 5503               -0.013146                  0.0628         0.2370
# 5504                0.029307                  0.0657         0.2749
# 5505                0.093615                  0.1128         0.3067
# 5506                0.110848                  0.1373         0.2785
# 5507                0.120739                  0.1529         0.2575
#
#       pending_ratio_mm  pending_ratio_yy
# 0             0.000500               NaN
# 1             0.400000               NaN
# 2             0.571429               NaN
# 3             0.090909               NaN
# 4             0.000000               NaN
# ...                ...               ...
# 5503          0.224174           -0.0361
# 5504          0.159916           -0.0523
# 5505          0.115678           -0.0404
# 5506         -0.091947           -0.0555
# 5507         -0.075404           -0.0157
#
# [5508 rows x 45 columns]

# %%
customDescription(df)
# Out:
#                                                    type  count  nunique  null  \
# month_date_yyyymm                        datetime64[ns]   5508      108     0
# state                                            object   5508       51     0
# state_id                                         object   5508       51     0
# median_listing_price                              int64   5508     2617     0
# median_listing_price_mm                         float64   5508     4792     0
# median_listing_price_yy                         float64   4896     2151   612
# active_listing_count                              int64   5508     5034     0
# active_listing_count_mm                         float64   5508     5502     0
# active_listing_count_yy                         float64   4896     3822   612
# median_days_on_market                             int64   5508      130     0
# median_days_on_market_mm                        float64   5508     1392     0
# median_days_on_market_yy                        float64   4896     2508   612
# new_listing_count                                 int64   5508     3840     0
# new_listing_count_mm                            float64   5508     5458     0
# new_listing_count_yy                            float64   4896     3006   612
# price_increased_count                             int64   5508     1084     0
# price_increased_count_mm                        float64   5508     3466     0
# price_increased_count_yy                        float64   4894     3217   614
# price_increased_share                           float64   5508      581     0
# price_increased_share_mm                        float64   5508     3905     0
# price_increased_share_yy                        float64   4896      642   612
# price_reduced_count                               int64   5508     3200     0
# price_reduced_count_mm                          float64   5508     5336     0
# price_reduced_count_yy                          float64   4896     4064   612
# price_reduced_share                             float64   5508     1909     0
# price_reduced_share_mm                          float64   5508     5438     0
# price_reduced_share_yy                          float64   4896     1594   612
# pending_listing_count                           float64   5481     4612    27
# pending_listing_count_mm                        float64   5507     5437     1
# pending_listing_count_yy                        float64   4860     3786   648
# median_listing_price_per_square_foot              int64   5508      478     0
# median_listing_price_per_square_foot_mm         float64   5508     1566     0
# median_listing_price_per_square_foot_yy         float64   4896     2066   612
# median_square_feet                                int64   5508     1059     0
# median_square_feet_mm                           float64   5508     4767     0
# median_square_feet_yy                           float64   4896     1524   612
# average_listing_price                             int64   5508     5488     0
# average_listing_price_mm                        float64   5508     5508     0
# average_listing_price_yy                        float64   4896     2314   612
# total_listing_count                               int64   5508     5173     0
# total_listing_count_mm                          float64   5508     5502     0
# total_listing_count_yy                          float64   4896     3398   612
# pending_ratio                                   float64   5481     4443    27
# pending_ratio_mm                                float64   5507     5455     1
# pending_ratio_yy                                float64   4861     3648   647
#
#                                                 mode  least_frequent  \
# month_date_yyyymm                                NaN             NaN
# state                                            NaN             NaN
# state_id                                         NaN             NaN
# median_listing_price                     299900.0000             NaN
# median_listing_price_mm                       0.0000             NaN
# median_listing_price_yy                       0.0000             NaN
# active_listing_count                             NaN             NaN
# active_listing_count_mm                          NaN             NaN
# active_listing_count_yy                          NaN             NaN
# median_days_on_market                        51.0000             NaN
# median_days_on_market_mm                      0.0000             NaN
# median_days_on_market_yy                      0.0000             NaN
# new_listing_count                                NaN             NaN
# new_listing_count_mm                          0.0000             NaN
# new_listing_count_yy                          0.0000             NaN
# price_increased_count                        20.0000             NaN
# price_increased_count_mm                      0.0000             NaN
# price_increased_count_yy                      0.0000             NaN
# price_increased_share                         0.0055             NaN
# price_increased_share_mm                      0.0000             NaN
# price_increased_share_yy                     -0.0009             NaN
# price_reduced_count                         580.0000             NaN
# price_reduced_count_mm                        0.0000             NaN
# price_reduced_count_yy                        0.0000             NaN
# price_reduced_share                              NaN             NaN
# price_reduced_share_mm                        0.0000             NaN
# price_reduced_share_yy                           NaN             NaN
# pending_listing_count                            NaN             NaN
# pending_listing_count_mm                      0.0000             NaN
# pending_listing_count_yy                         NaN             NaN
# median_listing_price_per_square_foot        117.0000             NaN
# median_listing_price_per_square_foot_mm       0.0000             NaN
# median_listing_price_per_square_foot_yy       0.0655             NaN
# median_square_feet                         2000.0000             NaN
# median_square_feet_mm                         0.0000             NaN
# median_square_feet_yy                         0.0000             NaN
# average_listing_price                            NaN             NaN
# average_listing_price_mm                         NaN             NaN
# average_listing_price_yy                      0.0529             NaN
# total_listing_count                              NaN             NaN
# total_listing_count_mm                           NaN             NaN
# total_listing_count_yy                           NaN             NaN
# pending_ratio                                    NaN             NaN
# pending_ratio_mm                              0.0000             NaN
# pending_ratio_yy                                 NaN             NaN
#
#                                                   mean                  min  \
# month_date_yyyymm                                  NaN  2016-07-01 00:00:00
# state                                              NaN                  NaN
# state_id                                           NaN                  NaN
# median_listing_price                     360216.386892             129913.0
# median_listing_price_mm                    2476.961124            -0.103768
# median_listing_price_yy                       0.068814              -0.2071
# active_listing_count                      17650.938453                720.0
# active_listing_count_mm                     265.792889            -0.307421
# active_listing_count_yy                      -0.012367              -0.7173
# median_days_on_market                        58.554103                 13.0
# median_days_on_market_mm                      0.599418            -0.604651
# median_days_on_market_yy                     -0.006308              -0.7155
# new_listing_count                          8207.112564                290.0
# new_listing_count_mm                         91.850143            -0.691244
# new_listing_count_yy                         -0.013270              -0.7398
# price_increased_count                       599.119463                  0.0
# price_increased_count_mm                      8.110739                 -1.0
# price_increased_count_yy                      0.144082                 -1.0
# price_increased_share                         0.014464                  0.0
# price_increased_share_mm                      0.064986                 -1.0
# price_increased_share_yy                     -0.000509              -0.1175
# price_reduced_count                        5142.209150                 72.0
# price_reduced_count_mm                       75.705571            -0.762456
# price_reduced_count_yy                        0.076649              -0.8464
# price_reduced_share                           0.132805               0.0254
# price_reduced_share_mm                        0.017725            -0.686779
# price_reduced_share_yy                        0.002088              -0.2464
# pending_listing_count                      8550.248312                  0.0
# pending_listing_count_mm                     75.303367                 -1.0
# pending_listing_count_yy                      0.228948              -0.9777
# median_listing_price_per_square_foot        195.895062                 79.0
# median_listing_price_per_square_foot_mm       1.329508             -0.11747
# median_listing_price_per_square_foot_yy       0.075114               -0.095
# median_square_feet                         1908.460784                987.0
# median_square_feet_mm                        17.816010            -0.100996
# median_square_feet_yy                        -0.003240              -0.3058
# average_listing_price                    568693.404139             206417.0
# average_listing_price_mm                   3871.307741            -0.451198
# average_listing_price_yy                      0.066544              -0.3896
# total_listing_count                       26086.285403                803.0
# total_listing_count_mm                      340.151316            -0.359258
# total_listing_count_yy                       -0.019375              -0.4954
# pending_ratio                                 0.578411                  0.0
# pending_ratio_mm                              0.044760                 -1.0
# pending_ratio_yy                              0.034240              -2.5872
#
#                                                          max
# month_date_yyyymm                        2025-06-01 00:00:00
# state                                                    NaN
# state_id                                                 NaN
# median_listing_price                                886500.0
# median_listing_price_mm                             649000.0
# median_listing_price_yy                               0.4101
# active_listing_count                                182589.0
# active_listing_count_mm                             136780.0
# active_listing_count_yy                               2.3532
# median_days_on_market                                  157.0
# median_days_on_market_mm                                89.0
# median_days_on_market_yy                              1.6271
# new_listing_count                                    53332.0
# new_listing_count_mm                                 47100.0
# new_listing_count_yy                                  2.0644
# price_increased_count                                 9466.0
# price_increased_count_mm                              7556.0
# price_increased_count_yy                                57.0
# price_increased_share                                 0.1302
# price_increased_share_mm                                68.2
# price_increased_share_yy                              0.1029
# price_reduced_count                                  71888.0
# price_reduced_count_mm                               40688.0
# price_reduced_count_yy                                5.7706
# price_reduced_share                                   0.4089
# price_reduced_share_mm                              1.793201
# price_reduced_share_yy                                0.3025
# pending_listing_count                                82071.0
# pending_listing_count_mm                             57761.0
# pending_listing_count_yy                             16.1045
# median_listing_price_per_square_foot                   737.0
# median_listing_price_per_square_foot_mm                499.0
# median_listing_price_per_square_foot_yy               0.4914
# median_square_feet                                    2798.0
# median_square_feet_mm                                 2640.0
# median_square_feet_yy                                 0.2676
# average_listing_price                              1730505.0
# average_listing_price_mm                           1262800.0
# average_listing_price_yy                              1.0508
# total_listing_count                                 231347.0
# total_listing_count_mm                              194340.0
# total_listing_count_yy                                1.1688
# pending_ratio                                          3.212
# pending_ratio_mm                                        81.0
# pending_ratio_yy                                      2.5949

# %%
df2 = df[df['month_date_yyyymm'] >= '2017-07-01']

# %%
customDescription(df2)
# Out:
#                                                    type  count  nunique  null  \
# month_date_yyyymm                        datetime64[ns]   4896       96     0
# state                                            object   4896       51     0
# state_id                                         object   4896       51     0
# median_listing_price                              int64   4896     2389     0
# median_listing_price_mm                         float64   4896     4295     0
# median_listing_price_yy                         float64   4896     2151     0
# active_listing_count                              int64   4896     4492     0
# active_listing_count_mm                         float64   4896     4891     0
# active_listing_count_yy                         float64   4896     3822     0
# median_days_on_market                             int64   4896      125     0
# median_days_on_market_mm                        float64   4896     1279     0
# median_days_on_market_yy                        float64   4896     2508     0
# new_listing_count                                 int64   4896     3527     0
# new_listing_count_mm                            float64   4896     4858     0
# new_listing_count_yy                            float64   4896     3006     0
# price_increased_count                             int64   4896      998     0
# price_increased_count_mm                        float64   4896     3098     0
# price_increased_count_yy                        float64   4894     3217     2
# price_increased_share                           float64   4896      560     0
# price_increased_share_mm                        float64   4896     3563     0
# price_increased_share_yy                        float64   4896      642     0
# price_reduced_count                               int64   4896     2932     0
# price_reduced_count_mm                          float64   4896     4740     0
# price_reduced_count_yy                          float64   4896     4064     0
# price_reduced_share                             float64   4896     1856     0
# price_reduced_share_mm                          float64   4896     4845     0
# price_reduced_share_yy                          float64   4896     1594     0
# pending_listing_count                           float64   4873     4204    23
# pending_listing_count_mm                        float64   4896     4840     0
# pending_listing_count_yy                        float64   4860     3786    36
# median_listing_price_per_square_foot              int64   4896      464     0
# median_listing_price_per_square_foot_mm         float64   4896     1497     0
# median_listing_price_per_square_foot_yy         float64   4896     2066     0
# median_square_feet                                int64   4896     1013     0
# median_square_feet_mm                           float64   4896     4299     0
# median_square_feet_yy                           float64   4896     1524     0
# average_listing_price                             int64   4896     4880     0
# average_listing_price_mm                        float64   4896     4896     0
# average_listing_price_yy                        float64   4896     2314     0
# total_listing_count                               int64   4896     4622     0
# total_listing_count_mm                          float64   4896     4892     0
# total_listing_count_yy                          float64   4896     3398     0
# pending_ratio                                   float64   4873     4085    23
# pending_ratio_mm                                float64   4896     4858     0
# pending_ratio_yy                                float64   4861     3648    35
#
#                                                 mode  least_frequent  \
# month_date_yyyymm                                NaN             NaN
# state                                            NaN             NaN
# state_id                                         NaN             NaN
# median_listing_price                     299900.0000             NaN
# median_listing_price_mm                       0.0000             NaN
# median_listing_price_yy                       0.0000             NaN
# active_listing_count                             NaN             NaN
# active_listing_count_mm                          NaN             NaN
# active_listing_count_yy                          NaN             NaN
# median_days_on_market                        44.0000             NaN
# median_days_on_market_mm                      0.0000             NaN
# median_days_on_market_yy                      0.0000             NaN
# new_listing_count                                NaN             NaN
# new_listing_count_mm                          0.0000             NaN
# new_listing_count_yy                          0.0000             NaN
# price_increased_count                        20.0000             NaN
# price_increased_count_mm                      0.0000             NaN
# price_increased_count_yy                      0.0000             NaN
# price_increased_share                         0.0055             NaN
# price_increased_share_mm                      0.0000             NaN
# price_increased_share_yy                     -0.0009             NaN
# price_reduced_count                         580.0000             NaN
# price_reduced_count_mm                        0.0000             NaN
# price_reduced_count_yy                        0.0000             NaN
# price_reduced_share                              NaN             NaN
# price_reduced_share_mm                        0.0000             NaN
# price_reduced_share_yy                           NaN             NaN
# pending_listing_count                            NaN             NaN
# pending_listing_count_mm                      0.0000             NaN
# pending_listing_count_yy                         NaN             NaN
# median_listing_price_per_square_foot             NaN             NaN
# median_listing_price_per_square_foot_mm       0.0000             NaN
# median_listing_price_per_square_foot_yy       0.0655             NaN
# median_square_feet                         2000.0000             NaN
# median_square_feet_mm                         0.0000             NaN
# median_square_feet_yy                         0.0000             NaN
# average_listing_price                            NaN             NaN
# average_listing_price_mm                         NaN             NaN
# average_listing_price_yy                      0.0529             NaN
# total_listing_count                              NaN             NaN
# total_listing_count_mm                           NaN             NaN
# total_listing_count_yy                           NaN             NaN
# pending_ratio                                    NaN             NaN
# pending_ratio_mm                              0.0000             NaN
# pending_ratio_yy                                 NaN             NaN
#
#                                                   mean                  min  \
# month_date_yyyymm                                  NaN  2017-07-01 00:00:00
# state                                              NaN                  NaN
# state_id                                           NaN                  NaN
# median_listing_price                     371457.442402             144900.0
# median_listing_price_mm                       0.005309            -0.103768
# median_listing_price_yy                       0.068814              -0.2071
# active_listing_count                      16682.098652                720.0
# active_listing_count_mm                       0.000231            -0.307421
# active_listing_count_yy                      -0.012367              -0.7173
# median_days_on_market                        56.864379                 13.0
# median_days_on_market_mm                      0.008552            -0.604651
# median_days_on_market_yy                     -0.006308              -0.7155
# new_listing_count                          8122.767157                290.0
# new_listing_count_mm                          0.015546            -0.691244
# new_listing_count_yy                         -0.013270              -0.7398
# price_increased_count                       572.545752                  0.0
# price_increased_count_mm                      0.071544                 -1.0
# price_increased_count_yy                      0.144082                 -1.0
# price_increased_share                         0.014501                  0.0
# price_increased_share_mm                      0.065660                 -1.0
# price_increased_share_yy                     -0.000509              -0.1175
# price_reduced_count                        4956.882761                 72.0
# price_reduced_count_mm                        0.026359            -0.762456
# price_reduced_count_yy                        0.076649              -0.8464
# price_reduced_share                           0.131748               0.0254
# price_reduced_share_mm                        0.016885            -0.686779
# price_reduced_share_yy                        0.002088              -0.2464
# pending_listing_count                      8709.798276                  1.0
# pending_listing_count_mm                      0.040064            -0.973371
# pending_listing_count_yy                      0.228948              -0.9777
# median_listing_price_per_square_foot        202.355801                 83.0
# median_listing_price_per_square_foot_mm       0.005802             -0.11747
# median_listing_price_per_square_foot_yy       0.075114               -0.095
# median_square_feet                         1906.746732                987.0
# median_square_feet_mm                        -0.000337            -0.100996
# median_square_feet_yy                        -0.003240              -0.3058
# average_listing_price                    586064.333742             210665.0
# average_listing_price_mm                      0.005413            -0.451198
# average_listing_price_yy                      0.066544              -0.3896
# total_listing_count                       25278.144199                803.0
# total_listing_count_mm                        0.001265            -0.359258
# total_listing_count_yy                       -0.019375              -0.4954
# pending_ratio                                 0.619495               0.0003
# pending_ratio_mm                              0.044887            -0.972069
# pending_ratio_yy                              0.034240              -2.5872
#
#                                                          max
# month_date_yyyymm                        2025-06-01 00:00:00
# state                                                    NaN
# state_id                                                 NaN
# median_listing_price                                886500.0
# median_listing_price_mm                             0.113545
# median_listing_price_yy                               0.4101
# active_listing_count                                182589.0
# active_listing_count_mm                             0.611643
# active_listing_count_yy                               2.3532
# median_days_on_market                                  152.0
# median_days_on_market_mm                              0.5625
# median_days_on_market_yy                              1.6271
# new_listing_count                                    53332.0
# new_listing_count_mm                                2.245726
# new_listing_count_yy                                  2.0644
# price_increased_count                                 9466.0
# price_increased_count_mm                                63.0
# price_increased_count_yy                                57.0
# price_increased_share                                 0.1302
# price_increased_share_mm                                68.2
# price_increased_share_yy                              0.1029
# price_reduced_count                                  71888.0
# price_reduced_count_mm                              2.949778
# price_reduced_count_yy                                5.7706
# price_reduced_share                                   0.4089
# price_reduced_share_mm                              1.793201
# price_reduced_share_yy                                0.3025
# pending_listing_count                                82071.0
# pending_listing_count_mm                                79.0
# pending_listing_count_yy                             16.1045
# median_listing_price_per_square_foot                   737.0
# median_listing_price_per_square_foot_mm                 0.12
# median_listing_price_per_square_foot_yy               0.4914
# median_square_feet                                    2798.0
# median_square_feet_mm                               0.178375
# median_square_feet_yy                                 0.2676
# average_listing_price                              1730505.0
# average_listing_price_mm                            0.924406
# average_listing_price_yy                              1.0508
# total_listing_count                                 231347.0
# total_listing_count_mm                              0.773585
# total_listing_count_yy                                1.1688
# pending_ratio                                          3.212
# pending_ratio_mm                                        81.0
# pending_ratio_yy                                      2.5949

# %%
df2[['price_increased_count_yy','pending_listing_count','pending_listing_count_yy','pending_ratio','pending_ratio_yy']] = \
    df2[['price_increased_count_yy','pending_listing_count','pending_listing_count_yy','pending_ratio','pending_ratio_yy']].fillna(0)

# %%
customDescription(df2)
# Out:
#                                                    type  count  nunique  null  \
# month_date_yyyymm                        datetime64[ns]   4896       96     0
# state                                            object   4896       51     0
# state_id                                         object   4896       51     0
# median_listing_price                              int64   4896     2389     0
# median_listing_price_mm                         float64   4896     4295     0
# median_listing_price_yy                         float64   4896     2151     0
# active_listing_count                              int64   4896     4492     0
# active_listing_count_mm                         float64   4896     4891     0
# active_listing_count_yy                         float64   4896     3822     0
# median_days_on_market                             int64   4896      125     0
# median_days_on_market_mm                        float64   4896     1279     0
# median_days_on_market_yy                        float64   4896     2508     0
# new_listing_count                                 int64   4896     3527     0
# new_listing_count_mm                            float64   4896     4858     0
# new_listing_count_yy                            float64   4896     3006     0
# price_increased_count                             int64   4896      998     0
# price_increased_count_mm                        float64   4896     3098     0
# price_increased_count_yy                        float64   4896     3217     0
# price_increased_share                           float64   4896      560     0
# price_increased_share_mm                        float64   4896     3563     0
# price_increased_share_yy                        float64   4896      642     0
# price_reduced_count                               int64   4896     2932     0
# price_reduced_count_mm                          float64   4896     4740     0
# price_reduced_count_yy                          float64   4896     4064     0
# price_reduced_share                             float64   4896     1856     0
# price_reduced_share_mm                          float64   4896     4845     0
# price_reduced_share_yy                          float64   4896     1594     0
# pending_listing_count                           float64   4896     4205     0
# pending_listing_count_mm                        float64   4896     4840     0
# pending_listing_count_yy                        float64   4896     3786     0
# median_listing_price_per_square_foot              int64   4896      464     0
# median_listing_price_per_square_foot_mm         float64   4896     1497     0
# median_listing_price_per_square_foot_yy         float64   4896     2066     0
# median_square_feet                                int64   4896     1013     0
# median_square_feet_mm                           float64   4896     4299     0
# median_square_feet_yy                           float64   4896     1524     0
# average_listing_price                             int64   4896     4880     0
# average_listing_price_mm                        float64   4896     4896     0
# average_listing_price_yy                        float64   4896     2314     0
# total_listing_count                               int64   4896     4622     0
# total_listing_count_mm                          float64   4896     4892     0
# total_listing_count_yy                          float64   4896     3398     0
# pending_ratio                                   float64   4896     4086     0
# pending_ratio_mm                                float64   4896     4858     0
# pending_ratio_yy                                float64   4896     3648     0
#
#                                                 mode  least_frequent  \
# month_date_yyyymm                                NaN             NaN
# state                                            NaN             NaN
# state_id                                         NaN             NaN
# median_listing_price                     299900.0000             NaN
# median_listing_price_mm                       0.0000             NaN
# median_listing_price_yy                       0.0000             NaN
# active_listing_count                             NaN             NaN
# active_listing_count_mm                          NaN             NaN
# active_listing_count_yy                          NaN             NaN
# median_days_on_market                        44.0000             NaN
# median_days_on_market_mm                      0.0000             NaN
# median_days_on_market_yy                      0.0000             NaN
# new_listing_count                                NaN             NaN
# new_listing_count_mm                          0.0000             NaN
# new_listing_count_yy                          0.0000             NaN
# price_increased_count                        20.0000             NaN
# price_increased_count_mm                      0.0000             NaN
# price_increased_count_yy                      0.0000             NaN
# price_increased_share                         0.0055             NaN
# price_increased_share_mm                      0.0000             NaN
# price_increased_share_yy                     -0.0009             NaN
# price_reduced_count                         580.0000             NaN
# price_reduced_count_mm                        0.0000             NaN
# price_reduced_count_yy                        0.0000             NaN
# price_reduced_share                              NaN             NaN
# price_reduced_share_mm                        0.0000             NaN
# price_reduced_share_yy                           NaN             NaN
# pending_listing_count                         0.0000             NaN
# pending_listing_count_mm                      0.0000             NaN
# pending_listing_count_yy                      0.0000             NaN
# median_listing_price_per_square_foot             NaN             NaN
# median_listing_price_per_square_foot_mm       0.0000             NaN
# median_listing_price_per_square_foot_yy       0.0655             NaN
# median_square_feet                         2000.0000             NaN
# median_square_feet_mm                         0.0000             NaN
# median_square_feet_yy                         0.0000             NaN
# average_listing_price                            NaN             NaN
# average_listing_price_mm                         NaN             NaN
# average_listing_price_yy                      0.0529             NaN
# total_listing_count                              NaN             NaN
# total_listing_count_mm                           NaN             NaN
# total_listing_count_yy                           NaN             NaN
# pending_ratio                                 0.0000             NaN
# pending_ratio_mm                              0.0000             NaN
# pending_ratio_yy                              0.0000             NaN
#
#                                                   mean                  min  \
# month_date_yyyymm                                  NaN  2017-07-01 00:00:00
# state                                              NaN                  NaN
# state_id                                           NaN                  NaN
# median_listing_price                     371457.442402             144900.0
# median_listing_price_mm                       0.005309            -0.103768
# median_listing_price_yy                       0.068814              -0.2071
# active_listing_count                      16682.098652                720.0
# active_listing_count_mm                       0.000231            -0.307421
# active_listing_count_yy                      -0.012367              -0.7173
# median_days_on_market                        56.864379                 13.0
# median_days_on_market_mm                      0.008552            -0.604651
# median_days_on_market_yy                     -0.006308              -0.7155
# new_listing_count                          8122.767157                290.0
# new_listing_count_mm                          0.015546            -0.691244
# new_listing_count_yy                         -0.013270              -0.7398
# price_increased_count                       572.545752                  0.0
# price_increased_count_mm                      0.071544                 -1.0
# price_increased_count_yy                      0.144023                 -1.0
# price_increased_share                         0.014501                  0.0
# price_increased_share_mm                      0.065660                 -1.0
# price_increased_share_yy                     -0.000509              -0.1175
# price_reduced_count                        4956.882761                 72.0
# price_reduced_count_mm                        0.026359            -0.762456
# price_reduced_count_yy                        0.076649              -0.8464
# price_reduced_share                           0.131748               0.0254
# price_reduced_share_mm                        0.016885            -0.686779
# price_reduced_share_yy                        0.002088              -0.2464
# pending_listing_count                      8668.882149                  0.0
# pending_listing_count_mm                      0.040064            -0.973371
# pending_listing_count_yy                      0.227264              -0.9777
# median_listing_price_per_square_foot        202.355801                 83.0
# median_listing_price_per_square_foot_mm       0.005802             -0.11747
# median_listing_price_per_square_foot_yy       0.075114               -0.095
# median_square_feet                         1906.746732                987.0
# median_square_feet_mm                        -0.000337            -0.100996
# median_square_feet_yy                        -0.003240              -0.3058
# average_listing_price                    586064.333742             210665.0
# average_listing_price_mm                      0.005413            -0.451198
# average_listing_price_yy                      0.066544              -0.3896
# total_listing_count                       25278.144199                803.0
# total_listing_count_mm                        0.001265            -0.359258
# total_listing_count_yy                       -0.019375              -0.4954
# pending_ratio                                 0.616585                  0.0
# pending_ratio_mm                              0.044887            -0.972069
# pending_ratio_yy                              0.033995              -2.5872
#
#                                                          max
# month_date_yyyymm                        2025-06-01 00:00:00
# state                                                    NaN
# state_id                                                 NaN
# median_listing_price                                886500.0
# median_listing_price_mm                             0.113545
# median_listing_price_yy                               0.4101
# active_listing_count                                182589.0
# active_listing_count_mm                             0.611643
# active_listing_count_yy                               2.3532
# median_days_on_market                                  152.0
# median_days_on_market_mm                              0.5625
# median_days_on_market_yy                              1.6271
# new_listing_count                                    53332.0
# new_listing_count_mm                                2.245726
# new_listing_count_yy                                  2.0644
# price_increased_count                                 9466.0
# price_increased_count_mm                                63.0
# price_increased_count_yy                                57.0
# price_increased_share                                 0.1302
# price_increased_share_mm                                68.2
# price_increased_share_yy                              0.1029
# price_reduced_count                                  71888.0
# price_reduced_count_mm                              2.949778
# price_reduced_count_yy                                5.7706
# price_reduced_share                                   0.4089
# price_reduced_share_mm                              1.793201
# price_reduced_share_yy                                0.3025
# pending_listing_count                                82071.0
# pending_listing_count_mm                                79.0
# pending_listing_count_yy                             16.1045
# median_listing_price_per_square_foot                   737.0
# median_listing_price_per_square_foot_mm                 0.12
# median_listing_price_per_square_foot_yy               0.4914
# median_square_feet                                    2798.0
# median_square_feet_mm                               0.178375
# median_square_feet_yy                                 0.2676
# average_listing_price                              1730505.0
# average_listing_price_mm                            0.924406
# average_listing_price_yy                              1.0508
# total_listing_count                                 231347.0
# total_listing_count_mm                              0.773585
# total_listing_count_yy                                1.1688
# pending_ratio                                          3.212
# pending_ratio_mm                                        81.0
# pending_ratio_yy                                      2.5949
