# %%
import os
from google.cloud import bigquery
from get_bq_data import get_bq_data
from model_trainer_2 import get_predictions
from dotenv import load_dotenv

load_dotenv()

os.environ['GOOGLE_APPLICATION_CREDENTIALS' ] = 'service_keys.json'

client = bigquery. Client()

# %%
def aggregate_data():
    """Load dataset, aggregate, and push to Supabase""" 

    existing_data = get_bq_data(client,"county_market") 

    return existing_data

# %%
df = aggregate_data()
df.sort_values(by=['year', 'month', 'state_num','county_num'], inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#         year  month  county_num  state_num  median_listing_price  \
# 0       2017      7           1          1                186500
# 1       2017      7           2          1                317900
# 2       2017      7           3          1                179900
# 3       2017      7           4          1                132450
# 4       2017      7           5          1                162500
# ...      ...    ...         ...        ...                   ...
# 295906  2025      9        2985         51                345000
# 295907  2025      9        2986         51               3478750
# 295908  2025      9        2987         51                410000
# 295909  2025      9        2988         51                238175
# 295910  2025      9        2989         51                338950
#
#         median_listing_price_mm  median_listing_price_yy  \
# 0                      0.166354                   0.0005
# 1                      3.607246                   0.0258
# 2                      0.149521                  -0.0380
# 3                      0.068145                  -0.1773
# 4                     -0.439655                   0.0841
# ...                         ...                      ...
# 295906                -0.028200                   0.1129
# 295907                 0.050200                   0.0091
# 295908                 0.018800                  -0.0108
# 295909                -0.114600                  -0.1394
# 295910                -0.188100                   0.0271
#
#         active_listing_count  active_listing_count_mm  \
# 0                        227                16.461538
# 1                       2606               371.285700
# 2                        141                -0.790801
# 3                         44                 4.500000
# 4                        214                -0.842299
# ...                      ...                      ...
# 295906                   130                 0.126100
# 295907                   265                -0.056900
# 295908                    70                -0.054100
# 295909                    30                 0.000000
# 295910                    29                 0.140000
#
#         active_listing_count_yy  ...  median_square_feet_yy  \
# 0                       -0.2305  ...                -0.0062
# 1                       -0.1088  ...                 0.0248
# 2                       -0.0140  ...                -0.0692
# 3                       -0.3803  ...                -0.1440
# 4                       -0.2161  ...                 0.0376
# ...                         ...  ...                    ...
# 295906                   0.4885  ...                 0.0031
# 295907                   0.1991  ...                 0.0133
# 295908                   0.4583  ...                -0.0847
# 295909                   0.0169  ...                -0.1729
# 295910                   0.5000  ...                 0.2140
#
#         average_listing_price  average_listing_price_mm  \
# 0                      210063                  0.131945
# 1                      432296                  1.974603
# 2                      215424                  0.086151
# 3                      155139                 -0.007828
# 4                      210885                 -0.429459
# ...                       ...                       ...
# 295906                 381188                 -0.033000
# 295907                6682801                  0.036100
# 295908                 481127                 -0.022000
# 295909                 275345                 -0.045000
# 295910                 494401                 -0.128400
#
#         average_listing_price_yy  total_listing_count  total_listing_count_mm  \
# 0                        -0.0152                  291               21.384615
# 1                         0.0658                 2698              384.428560
# 2                        -0.0624                  153               -0.773333
# 3                        -0.2019                   49                4.444445
# 4                         0.1254                  255               -0.857223
# ...                          ...                  ...                     ...
# 295906                    0.0494                  130                0.126100
# 295907                    0.0373                  318               -0.006300
# 295908                   -0.0605                   72               -0.027000
# 295909                   -0.2328                   33               -0.015200
# 295910                   -0.2993                   37                0.303600
#
#         total_listing_count_yy  pending_ratio  pending_ratio_mm  \
# 0                      -0.1961         0.2731        169.687500
# 1                      -0.0773         0.0361          4.308824
# 2                      -0.0613         0.0851         55.733334
# 3                      -0.3378         0.1136         -0.091200
# 4                      -0.1748         0.1729         -0.449188
# ...                        ...            ...               ...
# 295906                  0.4885         0.2760          0.116700
# 295907                  0.1648         0.2094          0.070600
# 295908                  0.5000         0.0286          0.070600
# 295909                 -0.0441         0.1667          0.000000
# 295910                  0.3519         0.2632          0.143200
#
#         pending_ratio_yy
# 0                 0.0392
# 1                 0.0000
# 2                -0.0408
# 3                 0.0714
# 4                 0.0447
# ...                  ...
# 295906            0.1316
# 295907           -0.0417
# 295908            0.0077
# 295909           -0.0367
# 295910           -0.1579
#
# [295911 rows x 46 columns]

# %%
from preprocessing_4 import preprocess_data_4

target_df = preprocess_data_4(25, df.copy())
prediction_df = target_df.copy()

# %%
def train_model(df, prediction_df):

    features = [
        "median_listing_price",
        "median_days_on_market"
    ]
    
    for feature in features:
        predictions = get_predictions(df, feature, 24)
        prediction_df[feature] = predictions

    for col in features:
        if col in prediction_df.columns:
            prediction_df[col] = prediction_df[col].astype(int)

    return prediction_df

# %%
preds = train_model(df, prediction_df)
# Out:
# Initial memory: 108.08 MB
# Final memory: 73.09 MB
# Reduced by 32.4%
# Validation RMSE: 164640.7345, RMSLE: 0.1347, MAE: 22991.1262, MAPE: 7.02%, R²: 0.6651
# Validation RMSE: 44459.0055, RMSLE: 0.1473, MAE: 26436.1718, MAPE: 9.24%, R²: 0.9630
# Validation RMSE: 51695.7699, RMSLE: 0.1633, MAE: 29373.4841, MAPE: 10.14%, R²: 0.9495
# Validation RMSE: 68895.2624, RMSLE: 0.1906, MAE: 37203.1718, MAPE: 12.34%, R²: 0.9094
# Validation RMSE: 64943.3300, RMSLE: 0.2000, MAE: 38138.4853, MAPE: 12.81%, R²: 0.9175
# Validation RMSE: 70771.7710, RMSLE: 0.2169, MAE: 44182.9267, MAPE: 14.47%, R²: 0.9064
# Validation RMSE: 73986.8734, RMSLE: 0.2128, MAE: 42129.9558, MAPE: 14.66%, R²: 0.8951
# Validation RMSE: 84229.2692, RMSLE: 0.2156, MAE: 46740.3663, MAPE: 14.99%, R²: 0.8624
# Validation RMSE: 63117.8387, RMSLE: 0.1985, MAE: 42552.2809, MAPE: 13.75%, R²: 0.9212
# Validation RMSE: 75612.7288, RMSLE: 0.2083, MAE: 43930.9573, MAPE: 15.08%, R²: 0.8908
# Validation RMSE: 69967.5439, RMSLE: 0.2058, MAE: 42579.2470, MAPE: 14.36%, R²: 0.9050
# Validation RMSE: 74412.1647, RMSLE: 0.2056, MAE: 44496.8687, MAPE: 14.43%, R²: 0.8925
# Validation RMSE: 70061.5039, RMSLE: 0.1898, MAE: 42234.3992, MAPE: 13.43%, R²: 0.9017
# Validation RMSE: 78295.2259, RMSLE: 0.2114, MAE: 45739.8033, MAPE: 14.63%, R²: 0.8746
# Validation RMSE: 72724.2469, RMSLE: 0.2011, MAE: 44782.5042, MAPE: 14.06%, R²: 0.8946
# Validation RMSE: 29.4386, RMSLE: 0.3889, MAE: 20.4599, MAPE: 27.94%, R²: 0.1967
# Validation RMSE: 28.2716, RMSLE: 0.4075, MAE: 18.9219, MAPE: 28.30%, R²: 0.1200
# Validation RMSE: 25.9158, RMSLE: 0.3932, MAE: 16.7536, MAPE: 26.93%, R²: 0.1279
# Validation RMSE: 25.3410, RMSLE: 0.4140, MAE: 17.6755, MAPE: 28.58%, R²: -0.0478
# Validation RMSE: 24.0459, RMSLE: 0.4000, MAE: 17.6307, MAPE: 27.74%, R²: -0.1164
# Validation RMSE: 23.2538, RMSLE: 0.3700, MAE: 16.6654, MAPE: 25.03%, R²: -0.0527
# Validation RMSE: 21.8282, RMSLE: 0.3330, MAE: 15.8191, MAPE: 23.28%, R²: 0.0399
# Validation RMSE: 22.4495, RMSLE: 0.3282, MAE: 16.6971, MAPE: 23.29%, R²: 0.0245
# Validation RMSE: 23.3275, RMSLE: 0.3107, MAE: 17.1575, MAPE: 22.21%, R²: 0.0520
# Validation RMSE: 23.9195, RMSLE: 0.2831, MAE: 17.5580, MAPE: 20.70%, R²: 0.1019
# Validation RMSE: 23.6522, RMSLE: 0.2574, MAE: 17.3844, MAPE: 19.04%, R²: 0.2006
# Validation RMSE: 26.3609, RMSLE: 0.3122, MAE: 20.0972, MAPE: 24.28%, R²: 0.2271
# Validation RMSE: 28.3943, RMSLE: 0.3711, MAE: 20.7779, MAPE: 27.77%, R²: 0.2354
# Validation RMSE: 25.1018, RMSLE: 0.3519, MAE: 16.7669, MAPE: 25.57%, R²: 0.1962
# Validation RMSE: 22.4266, RMSLE: 0.3564, MAE: 15.4207, MAPE: 25.25%, R²: 0.1004
# Validation RMSE: 22.8956, RMSLE: 0.3631, MAE: 16.3862, MAPE: 25.39%, R²: 0.0077
# Validation RMSE: 23.6442, RMSLE: 0.3731, MAE: 17.6288, MAPE: 25.68%, R²: -0.1456
# Validation RMSE: 24.5596, RMSLE: 0.3642, MAE: 18.1103, MAPE: 25.36%, R²: -0.1331
# Validation RMSE: 24.8959, RMSLE: 0.3519, MAE: 18.3801, MAPE: 24.63%, R²: -0.0958
# 🏃 View run LightGBM_Darts_Model_median_days_on_market at: http://127.0.0.1:5000/#/experiments/2/runs/ab31adc4cd8442eea698e5d9efdff7c5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
# Using LightGBM model for predictions
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.509406 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.533001
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.230265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.531819
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.209080 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.532013
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.281332 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.533024
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.205475 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.532737
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.072678 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.529201
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.176668 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.522874
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.123520 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.514859
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.159931 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.508286
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.203817 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.504410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.139984 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.500874
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.127300 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.497407
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.154620 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.495355
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.219729 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.495707
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.174671 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.498455
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.133347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.502642
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.124742 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.506107
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.143275 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.506504
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.086627 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.503667
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.292782 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.499423
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.160003 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.497000
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.197120 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.497582
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.166602 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.500917
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.157101 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 253997
# [LightGBM] [Info] Number of data points in the train set: 155428, number of used features: 998
# [LightGBM] [Info] Start training from score 0.506443

# %%
preds_2 = preds.copy()

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
latest_df = df.groupby("county_num").tail(1).reset_index(drop=True)
preds['year_month'] = (preds['year'] - 2025) * 12 + preds['month'] - 9
preds.drop(columns=['year', 'month'], inplace=True)
cols_order = ['year_month', 'county_num', 'state_num', 'median_listing_price', 'median_days_on_market']
preds = preds[cols_order]
preds = preds[preds['year_month'].isin([3,6,12])]
preds.loc[preds['year_month'] == 12, 'median_listing_price'] = preds.loc[preds['year_month'] == 12, 'median_listing_price'] * 1.15
preds.loc[preds['year_month'] == 6, 'median_listing_price'] = preds.loc[preds['year_month'] == 6, 'median_listing_price'] * 1.1

preds['appreciation'] = 0.0
for index, row in preds.iterrows():
    county_num = row['county_num']
    
    current_price = latest_df[(latest_df['county_num'] == county_num)]['median_listing_price'].values[0]
    predicted_price = row['median_listing_price']
    
    appreciation = ((predicted_price - current_price) / current_price) * 100
    preds.loc[index, 'appreciation'] = appreciation

def calculate_volatility(df):
    volatility = {}
    for county in df['county_num'].unique():
        county_data = df[df['county_num'] == county].sort_values(by=['year', 'month'])
        if len(county_data) >= 12:
            last_12_mm = county_data['median_listing_price_mm'].tail(12).values
            volatility[county] = np.std(last_12_mm) * 100
        else:
            volatility[county] = np.nan  # Not enough data to calculate volatility
    return volatility

volatility_data = calculate_volatility(df)

preds['volatility'] = 0.0  # Initialize Volatility column

for index, row in preds.iterrows():
    county_num = row['county_num']
    if county_num in volatility_data:
        preds.loc[index, 'volatility'] = volatility_data[county_num]
    else:
        preds.loc[index, 'volatility'] = np.nan

def normalize_days_on_market(preds):
    inv_days = preds.groupby('year_month')['median_days_on_market'].transform(
        lambda s: np.where(s != 0, 1 / s, 1)
    )

    scaler = MinMaxScaler()
    preds = preds.copy()
    preds['liquidity'] = scaler.fit_transform(inv_days.to_frame()) * 100
    return preds

preds = normalize_days_on_market(preds)
preds.drop(columns=['median_listing_price', 'median_days_on_market'], inplace=True)
preds['IOI'] = (0.4 * preds['appreciation']) + (0.3 * preds['liquidity']) - (0.3 * preds['volatility'])
preds['IOI'] = preds.groupby('year_month')['IOI'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))
preds['IOI'] = preds['IOI'] * 100
preds
# Out:
#        year_month  county_num  state_num  appreciation  volatility  liquidity  \
# 5978            3           1          1     -3.859071   29.202799   8.132890
# 5979            3           2          1     -2.885748   56.829187   5.816627
# 5980            3           3          1     -3.291890   28.611046   3.251905
# 5981            3           4          1     -9.748181   39.242287   4.746084
# 5982            3           5          1    -10.380753   31.609135   7.055270
# ...           ...         ...        ...           ...         ...        ...
# 71731          12        2985         51     -1.083333   24.290853  12.874419
# 71732          12        2986         51    -18.415438  293.956644   8.851304
# 71733          12        2987         51    -13.338244   38.155674  13.213099
# 71734          12        2988         51     17.963661   13.396858  11.645134
# 71735          12        2989         51     -9.750361   31.891073   9.244186
#
#              IOI
# 5978   79.026276
# 5979   75.158459
# 5980   78.549229
# 5981   76.153124
# 5982   77.381717
# ...          ...
# 71731  58.208573
# 71732  29.967011
# 71733  55.366700
# 71734  61.544740
# 71735  56.040346
#
# [14945 rows x 7 columns]

# %%
preds.to_csv("county_investment_insights.csv", index=False)
