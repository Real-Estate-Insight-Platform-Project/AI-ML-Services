# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("data\State_Processed.csv")

# %%
df
# Out:
#         state state_id  median_listing_price  median_listing_price_mm  \
# 0     Alabama       AL                198060                -0.004223
# 1     Alabama       AL                197116                -0.004766
# 2     Alabama       AL                198000                 0.004485
# 3     Alabama       AL                196250                -0.008838
# 4     Alabama       AL                195000                -0.006369
# ...       ...      ...                   ...                      ...
# 4942  Wyoming       WY                459900                 0.000381
# 4943  Wyoming       WY                476000                 0.035008
# 4944  Wyoming       WY                495000                 0.039916
# 4945  Wyoming       WY                496741                 0.003517
# 4946  Wyoming       WY                496647                -0.000189
#
#       median_listing_price_yy  active_listing_count  active_listing_count_mm  \
# 0                      0.0654                 26519                 0.002343
# 1                      0.0655                 26367                -0.005732
# 2                      0.0708                 26102                -0.010050
# 3                      0.0736                 25586                -0.019769
# 4                      0.0803                 24859                -0.028414
# ...                       ...                   ...                      ...
# 4942                   0.0243                  1826                -0.004362
# 4943                   0.0462                  1945                 0.065170
# 4944                   0.0623                  2208                 0.135219
# 4945                   0.0458                  2519                 0.140851
# 4946                   0.0137                  2771                 0.100040
#
#       active_listing_count_yy  median_days_on_market  \
# 0                     -0.1296                     75
# 1                     -0.1189                     77
# 2                     -0.1169                     79
# 3                     -0.1154                     83
# 4                     -0.1098                     88
# ...                       ...                    ...
# 4942                   0.1127                     68
# 4943                   0.1421                     57
# 4944                   0.1820                     51
# 4945                   0.1644                     50
# 4946                   0.1916                     52
#
#       median_days_on_market_mm  median_days_on_market_yy  new_listing_count  \
# 0                     0.027397                   -0.0385               7772
# 1                     0.026667                   -0.0667               7198
# 2                     0.025974                   -0.0706               6364
# 3                     0.050633                   -0.0625               6190
# 4                     0.060241                   -0.0591               5790
# ...                        ...                       ...                ...
# 4942                 -0.227273                   -0.0556                784
# 4943                 -0.161765                   -0.1172                942
# 4944                 -0.105263                    0.0000               1028
# 4945                 -0.019608                    0.0638               1146
# 4946                  0.040000                    0.0097               1004
#
#       new_listing_count_mm  new_listing_count_yy  price_increased_count  \
# 0                 0.019680                0.0021                    552
# 1                -0.073855                0.0456                    478
# 2                -0.115866               -0.0467                    436
# 3                -0.027341                0.0154                    514
# 4                -0.064620                0.0859                    548
# ...                    ...                   ...                    ...
# 4942              0.319865                0.1951                     12
# 4943              0.201531                0.1135                     16
# 4944              0.091295                0.1762                     12
# 4945              0.114786                0.1506                     14
# 4946             -0.123909                0.0681                     14
#
#       price_increased_count_mm  price_increased_count_yy  \
# 0                    -0.073826                    0.5000
# 1                    -0.134058                    0.0575
# 2                    -0.087866                    0.0283
# 3                     0.178899                   -0.0115
# 4                     0.066148                    0.4271
# ...                        ...                       ...
# 4942                 12.000000                   -0.2500
# 4943                  0.333333                   -0.2000
# 4944                 -0.250000                    0.0000
# 4945                  0.166667                    0.7500
# 4946                  0.000000                    0.1667
#
#       price_increased_share  price_increased_share_mm  \
# 0                    0.0155                 -0.043210
# 1                    0.0135                 -0.129032
# 2                    0.0128                 -0.051852
# 3                    0.0154                  0.203125
# 4                    0.0169                  0.097403
# ...                     ...                       ...
# 4942                 0.0041                  0.004100
# 4943                 0.0046                  0.121951
# 4944                 0.0033                 -0.282609
# 4945                 0.0032                 -0.030303
# 4946                 0.0033                  0.031250
#
#       price_increased_share_yy  price_reduced_count  price_reduced_count_mm  \
# 0                       0.0061                 6064                0.024670
# 1                       0.0018                 5938               -0.020778
# 2                       0.0017                 5564               -0.062984
# 3                       0.0011                 4886               -0.121855
# 4                       0.0067                 4416               -0.096193
# ...                        ...                  ...                     ...
# 4942                   -0.0018                  332                0.092105
# 4943                   -0.0019                  388                0.168675
# 4944                   -0.0004                  520                0.340206
# 4945                    0.0011                  682                0.311538
# 4946                    0.0001                  792                0.161290
#
#       price_reduced_count_yy  price_reduced_share  price_reduced_share_mm  \
# 0                    -0.0111               0.1704                0.055108
# 1                     0.0126               0.1660               -0.025822
# 2                    -0.0390               0.1633               -0.016265
# 3                    -0.0725               0.1469               -0.100429
# 4                     0.1191               0.1365               -0.070796
# ...                      ...                  ...                     ...
# 4942                  0.4310               0.1058               -0.034672
# 4943                  0.2357               0.1135                0.072779
# 4944                  0.3000               0.1354                0.192952
# 4945                  0.2724               0.1597                0.179468
# 4946                  0.3113               0.1817                0.137758
#
#       price_reduced_share_yy  pending_listing_count  pending_listing_count_mm  \
# 0                     0.0151                 2092.0                 -0.066071
# 1                     0.0134                 1965.0                 -0.060707
# 2                     0.0104                 1719.0                 -0.125191
# 3                     0.0021                 1668.0                 -0.029668
# 4                     0.0303                 1669.0                  0.000600
# ...                      ...                    ...                       ...
# 4942                  0.0271                  502.0                  0.154023
# 4943                  0.0121                  597.0                  0.189243
# 4944                  0.0166                  615.0                  0.030151
# 4945                  0.0161                  649.0                  0.055285
# 4946                  0.0266                  625.0                 -0.036980
#
#       pending_listing_count_yy  median_listing_price_per_square_foot  \
# 0                       0.1265                                    95
# 1                       0.0318                                    95
# 2                      -0.0095                                    96
# 3                       0.0312                                    96
# 4                       0.1498                                    96
# ...                        ...                                   ...
# 4942                   -0.0652                                   208
# 4943                    0.0093                                   209
# 4944                   -0.0144                                   211
# 4945                    0.0973                                   217
# 4946                    0.0056                                   218
#
#       median_listing_price_per_square_foot_mm  \
# 0                                    0.000000
# 1                                    0.000000
# 2                                    0.010526
# 3                                    0.000000
# 4                                    0.000000
# ...                                       ...
# 4942                                -0.004785
# 4943                                 0.004808
# 4944                                 0.009569
# 4945                                 0.028436
# 4946                                 0.004608
#
#       median_listing_price_per_square_foot_yy  median_square_feet  \
# 0                                      0.0378                2022
# 1                                      0.0379                2008
# 2                                      0.0455                2000
# 3                                      0.0467                2000
# 4                                      0.0467                2000
# ...                                       ...                 ...
# 4942                                   0.0800                2176
# 4943                                   0.0716                2204
# 4944                                   0.0443                2216
# 4945                                   0.0210                2209
# 4946                                   0.0071                2201
#
#       median_square_feet_mm  median_square_feet_yy  average_listing_price  \
# 0                  0.000495                 0.0233                 264342
# 1                 -0.006924                 0.0170                 263188
# 2                 -0.003984                 0.0209                 264218
# 3                  0.000000                 0.0256                 264749
# 4                  0.000000                 0.0262                 267844
# ...                     ...                    ...                    ...
# 4942               0.002303                -0.0357                1166754
# 4943               0.012868                -0.0267                1108065
# 4944               0.005445                -0.0353                1064091
# 4945              -0.003159                -0.0222                1166952
# 4946              -0.003622                -0.0353                1220190
#
#       average_listing_price_mm  average_listing_price_yy  total_listing_count  \
# 0                    -0.000707                    0.0543                28563
# 1                    -0.004366                    0.0500                28314
# 2                     0.003914                    0.0635                27851
# 3                     0.002010                    0.0578                27241
# 4                     0.011690                    0.0833                26511
# ...                        ...                       ...                  ...
# 4942                 -0.026201                    0.2582                 2318
# 4943                 -0.050301                    0.2097                 2535
# 4944                 -0.039685                    0.1772                 2816
# 4945                  0.096666                    0.1760                 3156
# 4946                  0.045621                    0.1624                 3394
#
#       total_listing_count_mm  total_listing_count_yy  pending_ratio  \
# 0                  -0.004288                 -0.1169         0.0789
# 1                  -0.008718                 -0.1101         0.0745
# 2                  -0.016352                 -0.1095         0.0659
# 3                  -0.021902                 -0.1076         0.0652
# 4                  -0.026798                 -0.0973         0.0671
# ...                      ...                     ...            ...
# 4942                0.029307                  0.0657         0.2749
# 4943                0.093615                  0.1128         0.3067
# 4944                0.110848                  0.1373         0.2785
# 4945                0.120739                  0.1529         0.2575
# 4946                0.075412                  0.1586         0.2254
#
#       pending_ratio_mm  pending_ratio_yy Region            Division  year  \
# 0            -0.067376            0.0179  South  East South Central  2017
# 1            -0.055767            0.0109  South  East South Central  2017
# 2            -0.115436            0.0071  South  East South Central  2017
# 3            -0.010622            0.0093  South  East South Central  2017
# 4             0.029141            0.0152  South  East South Central  2017
# ...                ...               ...    ...                 ...   ...
# 4942          0.159916           -0.0523   West            Mountain  2025
# 4943          0.115678           -0.0404   West            Mountain  2025
# 4944         -0.091947           -0.0555   West            Mountain  2025
# 4945         -0.075404           -0.0157   West            Mountain  2025
# 4946         -0.124660           -0.0417   West            Mountain  2025
#
#       month
# 0         7
# 1         8
# 2         9
# 3        10
# 4        11
# ...     ...
# 4942      3
# 4943      4
# 4944      5
# 4945      6
# 4946      7
#
# [4947 rows x 48 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
for state in df['state'].unique():
    state_data = df[df['state'] == state]
    plt.plot(state_data['year'].astype(str) + '-' + state_data['month'].astype(str), state_data['median_listing_price'], label=state)

plt.xlabel('Year-Month')
plt.ylabel('median_listing_price')
plt.title('Median Listing Price Over Time for Each State')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
for state in df['state'].unique():
    state_data = df[df['state'] == state]
    plt.plot(state_data['year'].astype(str) + '-' + state_data['month'].astype(str), state_data['average_listing_price'], label=state)

plt.xlabel('month_date_yyyymm')
plt.ylabel('average_listing_price')
plt.title('Average Listing Price Over Time for Each State')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
df
# Out:
#         state state_id  median_listing_price  median_listing_price_mm  \
# 0     Alabama       AL                198060                -0.004223
# 1     Alabama       AL                197116                -0.004766
# 2     Alabama       AL                198000                 0.004485
# 3     Alabama       AL                196250                -0.008838
# 4     Alabama       AL                195000                -0.006369
# ...       ...      ...                   ...                      ...
# 4942  Wyoming       WY                459900                 0.000381
# 4943  Wyoming       WY                476000                 0.035008
# 4944  Wyoming       WY                495000                 0.039916
# 4945  Wyoming       WY                496741                 0.003517
# 4946  Wyoming       WY                496647                -0.000189
#
#       median_listing_price_yy  active_listing_count  active_listing_count_mm  \
# 0                      0.0654                 26519                 0.002343
# 1                      0.0655                 26367                -0.005732
# 2                      0.0708                 26102                -0.010050
# 3                      0.0736                 25586                -0.019769
# 4                      0.0803                 24859                -0.028414
# ...                       ...                   ...                      ...
# 4942                   0.0243                  1826                -0.004362
# 4943                   0.0462                  1945                 0.065170
# 4944                   0.0623                  2208                 0.135219
# 4945                   0.0458                  2519                 0.140851
# 4946                   0.0137                  2771                 0.100040
#
#       active_listing_count_yy  median_days_on_market  \
# 0                     -0.1296                     75
# 1                     -0.1189                     77
# 2                     -0.1169                     79
# 3                     -0.1154                     83
# 4                     -0.1098                     88
# ...                       ...                    ...
# 4942                   0.1127                     68
# 4943                   0.1421                     57
# 4944                   0.1820                     51
# 4945                   0.1644                     50
# 4946                   0.1916                     52
#
#       median_days_on_market_mm  median_days_on_market_yy  new_listing_count  \
# 0                     0.027397                   -0.0385               7772
# 1                     0.026667                   -0.0667               7198
# 2                     0.025974                   -0.0706               6364
# 3                     0.050633                   -0.0625               6190
# 4                     0.060241                   -0.0591               5790
# ...                        ...                       ...                ...
# 4942                 -0.227273                   -0.0556                784
# 4943                 -0.161765                   -0.1172                942
# 4944                 -0.105263                    0.0000               1028
# 4945                 -0.019608                    0.0638               1146
# 4946                  0.040000                    0.0097               1004
#
#       new_listing_count_mm  new_listing_count_yy  price_increased_count  \
# 0                 0.019680                0.0021                    552
# 1                -0.073855                0.0456                    478
# 2                -0.115866               -0.0467                    436
# 3                -0.027341                0.0154                    514
# 4                -0.064620                0.0859                    548
# ...                    ...                   ...                    ...
# 4942              0.319865                0.1951                     12
# 4943              0.201531                0.1135                     16
# 4944              0.091295                0.1762                     12
# 4945              0.114786                0.1506                     14
# 4946             -0.123909                0.0681                     14
#
#       price_increased_count_mm  price_increased_count_yy  \
# 0                    -0.073826                    0.5000
# 1                    -0.134058                    0.0575
# 2                    -0.087866                    0.0283
# 3                     0.178899                   -0.0115
# 4                     0.066148                    0.4271
# ...                        ...                       ...
# 4942                 12.000000                   -0.2500
# 4943                  0.333333                   -0.2000
# 4944                 -0.250000                    0.0000
# 4945                  0.166667                    0.7500
# 4946                  0.000000                    0.1667
#
#       price_increased_share  price_increased_share_mm  \
# 0                    0.0155                 -0.043210
# 1                    0.0135                 -0.129032
# 2                    0.0128                 -0.051852
# 3                    0.0154                  0.203125
# 4                    0.0169                  0.097403
# ...                     ...                       ...
# 4942                 0.0041                  0.004100
# 4943                 0.0046                  0.121951
# 4944                 0.0033                 -0.282609
# 4945                 0.0032                 -0.030303
# 4946                 0.0033                  0.031250
#
#       price_increased_share_yy  price_reduced_count  price_reduced_count_mm  \
# 0                       0.0061                 6064                0.024670
# 1                       0.0018                 5938               -0.020778
# 2                       0.0017                 5564               -0.062984
# 3                       0.0011                 4886               -0.121855
# 4                       0.0067                 4416               -0.096193
# ...                        ...                  ...                     ...
# 4942                   -0.0018                  332                0.092105
# 4943                   -0.0019                  388                0.168675
# 4944                   -0.0004                  520                0.340206
# 4945                    0.0011                  682                0.311538
# 4946                    0.0001                  792                0.161290
#
#       price_reduced_count_yy  price_reduced_share  price_reduced_share_mm  \
# 0                    -0.0111               0.1704                0.055108
# 1                     0.0126               0.1660               -0.025822
# 2                    -0.0390               0.1633               -0.016265
# 3                    -0.0725               0.1469               -0.100429
# 4                     0.1191               0.1365               -0.070796
# ...                      ...                  ...                     ...
# 4942                  0.4310               0.1058               -0.034672
# 4943                  0.2357               0.1135                0.072779
# 4944                  0.3000               0.1354                0.192952
# 4945                  0.2724               0.1597                0.179468
# 4946                  0.3113               0.1817                0.137758
#
#       price_reduced_share_yy  pending_listing_count  pending_listing_count_mm  \
# 0                     0.0151                 2092.0                 -0.066071
# 1                     0.0134                 1965.0                 -0.060707
# 2                     0.0104                 1719.0                 -0.125191
# 3                     0.0021                 1668.0                 -0.029668
# 4                     0.0303                 1669.0                  0.000600
# ...                      ...                    ...                       ...
# 4942                  0.0271                  502.0                  0.154023
# 4943                  0.0121                  597.0                  0.189243
# 4944                  0.0166                  615.0                  0.030151
# 4945                  0.0161                  649.0                  0.055285
# 4946                  0.0266                  625.0                 -0.036980
#
#       pending_listing_count_yy  median_listing_price_per_square_foot  \
# 0                       0.1265                                    95
# 1                       0.0318                                    95
# 2                      -0.0095                                    96
# 3                       0.0312                                    96
# 4                       0.1498                                    96
# ...                        ...                                   ...
# 4942                   -0.0652                                   208
# 4943                    0.0093                                   209
# 4944                   -0.0144                                   211
# 4945                    0.0973                                   217
# 4946                    0.0056                                   218
#
#       median_listing_price_per_square_foot_mm  \
# 0                                    0.000000
# 1                                    0.000000
# 2                                    0.010526
# 3                                    0.000000
# 4                                    0.000000
# ...                                       ...
# 4942                                -0.004785
# 4943                                 0.004808
# 4944                                 0.009569
# 4945                                 0.028436
# 4946                                 0.004608
#
#       median_listing_price_per_square_foot_yy  median_square_feet  \
# 0                                      0.0378                2022
# 1                                      0.0379                2008
# 2                                      0.0455                2000
# 3                                      0.0467                2000
# 4                                      0.0467                2000
# ...                                       ...                 ...
# 4942                                   0.0800                2176
# 4943                                   0.0716                2204
# 4944                                   0.0443                2216
# 4945                                   0.0210                2209
# 4946                                   0.0071                2201
#
#       median_square_feet_mm  median_square_feet_yy  average_listing_price  \
# 0                  0.000495                 0.0233                 264342
# 1                 -0.006924                 0.0170                 263188
# 2                 -0.003984                 0.0209                 264218
# 3                  0.000000                 0.0256                 264749
# 4                  0.000000                 0.0262                 267844
# ...                     ...                    ...                    ...
# 4942               0.002303                -0.0357                1166754
# 4943               0.012868                -0.0267                1108065
# 4944               0.005445                -0.0353                1064091
# 4945              -0.003159                -0.0222                1166952
# 4946              -0.003622                -0.0353                1220190
#
#       average_listing_price_mm  average_listing_price_yy  total_listing_count  \
# 0                    -0.000707                    0.0543                28563
# 1                    -0.004366                    0.0500                28314
# 2                     0.003914                    0.0635                27851
# 3                     0.002010                    0.0578                27241
# 4                     0.011690                    0.0833                26511
# ...                        ...                       ...                  ...
# 4942                 -0.026201                    0.2582                 2318
# 4943                 -0.050301                    0.2097                 2535
# 4944                 -0.039685                    0.1772                 2816
# 4945                  0.096666                    0.1760                 3156
# 4946                  0.045621                    0.1624                 3394
#
#       total_listing_count_mm  total_listing_count_yy  pending_ratio  \
# 0                  -0.004288                 -0.1169         0.0789
# 1                  -0.008718                 -0.1101         0.0745
# 2                  -0.016352                 -0.1095         0.0659
# 3                  -0.021902                 -0.1076         0.0652
# 4                  -0.026798                 -0.0973         0.0671
# ...                      ...                     ...            ...
# 4942                0.029307                  0.0657         0.2749
# 4943                0.093615                  0.1128         0.3067
# 4944                0.110848                  0.1373         0.2785
# 4945                0.120739                  0.1529         0.2575
# 4946                0.075412                  0.1586         0.2254
#
#       pending_ratio_mm  pending_ratio_yy Region            Division  year  \
# 0            -0.067376            0.0179  South  East South Central  2017
# 1            -0.055767            0.0109  South  East South Central  2017
# 2            -0.115436            0.0071  South  East South Central  2017
# 3            -0.010622            0.0093  South  East South Central  2017
# 4             0.029141            0.0152  South  East South Central  2017
# ...                ...               ...    ...                 ...   ...
# 4942          0.159916           -0.0523   West            Mountain  2025
# 4943          0.115678           -0.0404   West            Mountain  2025
# 4944         -0.091947           -0.0555   West            Mountain  2025
# 4945         -0.075404           -0.0157   West            Mountain  2025
# 4946         -0.124660           -0.0417   West            Mountain  2025
#
#       month
# 0         7
# 1         8
# 2         9
# 3        10
# 4        11
# ...     ...
# 4942      3
# 4943      4
# 4944      5
# 4945      6
# 4946      7
#
# [4947 rows x 48 columns]

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='state_id', y='median_listing_price', data=df)
plt.title('Distribution of Median Listing Price by State')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='state_id', y='average_listing_price', data=df)
plt.title('Distribution of Average Listing Price by State')
plt.show()

# %%
df['state'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(14, 8))

# Loop through regions
for region in df['Region'].unique():
    region_data = df[df['Region'] == region]
    
    # Aggregate median listing price across states in the region
    region_monthly = region_data.groupby(['year', 'month'])['median_listing_price'].mean()
    
    # Create a combined year-month string for plotting
    dates = [f"{year}-{month}" for year, month in region_monthly.index]
    
    plt.plot(dates, region_monthly.values, label=region)

plt.xlabel('Year-Month')
plt.ylabel('Median Listing Price')
plt.title('Median Listing Price Over Time by Region')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(14, 8))

# Loop through regions
for region in df['Region'].unique():
    region_data = df[df['Region'] == region]
    
    # Aggregate median listing price across states in the region
    region_monthly = region_data.groupby(['year', 'month'])['average_listing_price'].mean()
    
    # Create a combined year-month string for plotting
    dates = [f"{year}-{month}" for year, month in region_monthly.index]
    
    plt.plot(dates, region_monthly.values, label=region)

plt.xlabel('Year-Month')
plt.ylabel('Average Listing Price')
plt.title('Average Listing Price Over Time by Region')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.figure(figsize=(14, 8))

# Loop through divisions
for division in df['Division'].unique():
    division_data = df[df['Division'] == division]

    # Aggregate average listing price across states in the division
    division_monthly = division_data.groupby(['year', 'month'])['average_listing_price'].mean()

    # Create a combined year-month string for plotting
    dates = [f"{year}-{month}" for year, month in division_monthly.index]
    
    plt.plot(dates, division_monthly.values, label=division)

plt.xlabel('Year-Month')
plt.ylabel('Average Listing Price')
plt.title('Average Listing Price Over Time by Division')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
# from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# from statsmodels.tsa.stattools import adfuller

# # Function to plot ACF and PACF
# def plot_acf_pacf(data, title):
#     fig, axes = plt.subplots(1, 2, figsize=(16, 4))
#     plot_acf(data, lags=30, ax=axes[0])
#     axes[0].set_title(f'{title} - ACF', fontsize=15)
#     plot_pacf(data, lags=30, ax=axes[1])
#     axes[1].set_title(f'{title} - PACF', fontsize=15)
#     plt.tight_layout()
#     plt.show()

# # Function to make series stationary
# def make_stationary(data):
#     result = adfuller(data.dropna())
#     if result[1] > 0.05:  # p-value > 0.05 means non-stationary
#         data = data.diff().dropna()
#     return data

# # Iterate through each state and plot
# for state in df['state'].unique():
#     state_data = df[df['state'] == state].sort_values(['year', 'month'])
    
#     # Extract median listing price time series
#     price_series = state_data['median_listing_price'].reset_index(drop=True)
    
#     # Make stationary if needed
#     stationary_series = make_stationary(price_series)
    
#     # Plot ACF and PACF
#     plot_acf_pacf(stationary_series, state)

# %%
df
# Out:
#         state state_id  median_listing_price  median_listing_price_mm  \
# 0     Alabama       AL                198060                -0.004223
# 1     Alabama       AL                197116                -0.004766
# 2     Alabama       AL                198000                 0.004485
# 3     Alabama       AL                196250                -0.008838
# 4     Alabama       AL                195000                -0.006369
# ...       ...      ...                   ...                      ...
# 4942  Wyoming       WY                459900                 0.000381
# 4943  Wyoming       WY                476000                 0.035008
# 4944  Wyoming       WY                495000                 0.039916
# 4945  Wyoming       WY                496741                 0.003517
# 4946  Wyoming       WY                496647                -0.000189
#
#       median_listing_price_yy  active_listing_count  active_listing_count_mm  \
# 0                      0.0654                 26519                 0.002343
# 1                      0.0655                 26367                -0.005732
# 2                      0.0708                 26102                -0.010050
# 3                      0.0736                 25586                -0.019769
# 4                      0.0803                 24859                -0.028414
# ...                       ...                   ...                      ...
# 4942                   0.0243                  1826                -0.004362
# 4943                   0.0462                  1945                 0.065170
# 4944                   0.0623                  2208                 0.135219
# 4945                   0.0458                  2519                 0.140851
# 4946                   0.0137                  2771                 0.100040
#
#       active_listing_count_yy  median_days_on_market  \
# 0                     -0.1296                     75
# 1                     -0.1189                     77
# 2                     -0.1169                     79
# 3                     -0.1154                     83
# 4                     -0.1098                     88
# ...                       ...                    ...
# 4942                   0.1127                     68
# 4943                   0.1421                     57
# 4944                   0.1820                     51
# 4945                   0.1644                     50
# 4946                   0.1916                     52
#
#       median_days_on_market_mm  median_days_on_market_yy  new_listing_count  \
# 0                     0.027397                   -0.0385               7772
# 1                     0.026667                   -0.0667               7198
# 2                     0.025974                   -0.0706               6364
# 3                     0.050633                   -0.0625               6190
# 4                     0.060241                   -0.0591               5790
# ...                        ...                       ...                ...
# 4942                 -0.227273                   -0.0556                784
# 4943                 -0.161765                   -0.1172                942
# 4944                 -0.105263                    0.0000               1028
# 4945                 -0.019608                    0.0638               1146
# 4946                  0.040000                    0.0097               1004
#
#       new_listing_count_mm  new_listing_count_yy  price_increased_count  \
# 0                 0.019680                0.0021                    552
# 1                -0.073855                0.0456                    478
# 2                -0.115866               -0.0467                    436
# 3                -0.027341                0.0154                    514
# 4                -0.064620                0.0859                    548
# ...                    ...                   ...                    ...
# 4942              0.319865                0.1951                     12
# 4943              0.201531                0.1135                     16
# 4944              0.091295                0.1762                     12
# 4945              0.114786                0.1506                     14
# 4946             -0.123909                0.0681                     14
#
#       price_increased_count_mm  price_increased_count_yy  \
# 0                    -0.073826                    0.5000
# 1                    -0.134058                    0.0575
# 2                    -0.087866                    0.0283
# 3                     0.178899                   -0.0115
# 4                     0.066148                    0.4271
# ...                        ...                       ...
# 4942                 12.000000                   -0.2500
# 4943                  0.333333                   -0.2000
# 4944                 -0.250000                    0.0000
# 4945                  0.166667                    0.7500
# 4946                  0.000000                    0.1667
#
#       price_increased_share  price_increased_share_mm  \
# 0                    0.0155                 -0.043210
# 1                    0.0135                 -0.129032
# 2                    0.0128                 -0.051852
# 3                    0.0154                  0.203125
# 4                    0.0169                  0.097403
# ...                     ...                       ...
# 4942                 0.0041                  0.004100
# 4943                 0.0046                  0.121951
# 4944                 0.0033                 -0.282609
# 4945                 0.0032                 -0.030303
# 4946                 0.0033                  0.031250
#
#       price_increased_share_yy  price_reduced_count  price_reduced_count_mm  \
# 0                       0.0061                 6064                0.024670
# 1                       0.0018                 5938               -0.020778
# 2                       0.0017                 5564               -0.062984
# 3                       0.0011                 4886               -0.121855
# 4                       0.0067                 4416               -0.096193
# ...                        ...                  ...                     ...
# 4942                   -0.0018                  332                0.092105
# 4943                   -0.0019                  388                0.168675
# 4944                   -0.0004                  520                0.340206
# 4945                    0.0011                  682                0.311538
# 4946                    0.0001                  792                0.161290
#
#       price_reduced_count_yy  price_reduced_share  price_reduced_share_mm  \
# 0                    -0.0111               0.1704                0.055108
# 1                     0.0126               0.1660               -0.025822
# 2                    -0.0390               0.1633               -0.016265
# 3                    -0.0725               0.1469               -0.100429
# 4                     0.1191               0.1365               -0.070796
# ...                      ...                  ...                     ...
# 4942                  0.4310               0.1058               -0.034672
# 4943                  0.2357               0.1135                0.072779
# 4944                  0.3000               0.1354                0.192952
# 4945                  0.2724               0.1597                0.179468
# 4946                  0.3113               0.1817                0.137758
#
#       price_reduced_share_yy  pending_listing_count  pending_listing_count_mm  \
# 0                     0.0151                 2092.0                 -0.066071
# 1                     0.0134                 1965.0                 -0.060707
# 2                     0.0104                 1719.0                 -0.125191
# 3                     0.0021                 1668.0                 -0.029668
# 4                     0.0303                 1669.0                  0.000600
# ...                      ...                    ...                       ...
# 4942                  0.0271                  502.0                  0.154023
# 4943                  0.0121                  597.0                  0.189243
# 4944                  0.0166                  615.0                  0.030151
# 4945                  0.0161                  649.0                  0.055285
# 4946                  0.0266                  625.0                 -0.036980
#
#       pending_listing_count_yy  median_listing_price_per_square_foot  \
# 0                       0.1265                                    95
# 1                       0.0318                                    95
# 2                      -0.0095                                    96
# 3                       0.0312                                    96
# 4                       0.1498                                    96
# ...                        ...                                   ...
# 4942                   -0.0652                                   208
# 4943                    0.0093                                   209
# 4944                   -0.0144                                   211
# 4945                    0.0973                                   217
# 4946                    0.0056                                   218
#
#       median_listing_price_per_square_foot_mm  \
# 0                                    0.000000
# 1                                    0.000000
# 2                                    0.010526
# 3                                    0.000000
# 4                                    0.000000
# ...                                       ...
# 4942                                -0.004785
# 4943                                 0.004808
# 4944                                 0.009569
# 4945                                 0.028436
# 4946                                 0.004608
#
#       median_listing_price_per_square_foot_yy  median_square_feet  \
# 0                                      0.0378                2022
# 1                                      0.0379                2008
# 2                                      0.0455                2000
# 3                                      0.0467                2000
# 4                                      0.0467                2000
# ...                                       ...                 ...
# 4942                                   0.0800                2176
# 4943                                   0.0716                2204
# 4944                                   0.0443                2216
# 4945                                   0.0210                2209
# 4946                                   0.0071                2201
#
#       median_square_feet_mm  median_square_feet_yy  average_listing_price  \
# 0                  0.000495                 0.0233                 264342
# 1                 -0.006924                 0.0170                 263188
# 2                 -0.003984                 0.0209                 264218
# 3                  0.000000                 0.0256                 264749
# 4                  0.000000                 0.0262                 267844
# ...                     ...                    ...                    ...
# 4942               0.002303                -0.0357                1166754
# 4943               0.012868                -0.0267                1108065
# 4944               0.005445                -0.0353                1064091
# 4945              -0.003159                -0.0222                1166952
# 4946              -0.003622                -0.0353                1220190
#
#       average_listing_price_mm  average_listing_price_yy  total_listing_count  \
# 0                    -0.000707                    0.0543                28563
# 1                    -0.004366                    0.0500                28314
# 2                     0.003914                    0.0635                27851
# 3                     0.002010                    0.0578                27241
# 4                     0.011690                    0.0833                26511
# ...                        ...                       ...                  ...
# 4942                 -0.026201                    0.2582                 2318
# 4943                 -0.050301                    0.2097                 2535
# 4944                 -0.039685                    0.1772                 2816
# 4945                  0.096666                    0.1760                 3156
# 4946                  0.045621                    0.1624                 3394
#
#       total_listing_count_mm  total_listing_count_yy  pending_ratio  \
# 0                  -0.004288                 -0.1169         0.0789
# 1                  -0.008718                 -0.1101         0.0745
# 2                  -0.016352                 -0.1095         0.0659
# 3                  -0.021902                 -0.1076         0.0652
# 4                  -0.026798                 -0.0973         0.0671
# ...                      ...                     ...            ...
# 4942                0.029307                  0.0657         0.2749
# 4943                0.093615                  0.1128         0.3067
# 4944                0.110848                  0.1373         0.2785
# 4945                0.120739                  0.1529         0.2575
# 4946                0.075412                  0.1586         0.2254
#
#       pending_ratio_mm  pending_ratio_yy Region            Division  year  \
# 0            -0.067376            0.0179  South  East South Central  2017
# 1            -0.055767            0.0109  South  East South Central  2017
# 2            -0.115436            0.0071  South  East South Central  2017
# 3            -0.010622            0.0093  South  East South Central  2017
# 4             0.029141            0.0152  South  East South Central  2017
# ...                ...               ...    ...                 ...   ...
# 4942          0.159916           -0.0523   West            Mountain  2025
# 4943          0.115678           -0.0404   West            Mountain  2025
# 4944         -0.091947           -0.0555   West            Mountain  2025
# 4945         -0.075404           -0.0157   West            Mountain  2025
# 4946         -0.124660           -0.0417   West            Mountain  2025
#
#       month
# 0         7
# 1         8
# 2         9
# 3        10
# 4        11
# ...     ...
# 4942      3
# 4943      4
# 4944      5
# 4945      6
# 4946      7
#
# [4947 rows x 48 columns]

# %%
# Sort by state and month
df = df.sort_values(["state", "year", "month"])

# Get latest record per state
latest_df = df.groupby("state").tail(1).reset_index(drop=True)

# Columns to keep unchanged
id_cols = ["state", "state_id", "year", "month", "Region", "Division"]

# Rename all other columns with _prev
rename_dict = {col: col + "_prev" for col in latest_df.columns if col not in id_cols}
input_df = latest_df.rename(columns=rename_dict)

# Add one month
if input_df["month"].iloc[0] == 12:
    input_df["month"] = 1
    input_df["year"] = input_df["year"] + 1
else:   
    input_df["month"] = input_df["month"] + 1

# Reorder columns
id_cols = ["year", "month", "state_id", "state"]
input_df = input_df[id_cols + [c for c in input_df.columns if c not in id_cols]]

# Columns to always keep
keep_cols = ["year", "month", "state_id", "state", "median_listing_price", "Region", "Division"]

# Lag columns
df_lagged = (
    df.groupby("state_id")
    .shift(1)
    .add_suffix("_prev")
  )

# Build final dataset
df_lagged = pd.concat([df[keep_cols], df_lagged], axis=1)

# Drop earliest month per state (no lag available)
df_lagged = df_lagged.dropna().reset_index(drop=True)

# %%
df_lagged.drop(columns=['state_prev', 'year_prev', 'month_prev', "Region_prev", "Division_prev"], inplace=True)

# %%
df_lagged
# Out:
#       year  month state_id    state  median_listing_price Region  \
# 0     2017      8       AL  Alabama                197116  South
# 1     2017      9       AL  Alabama                198000  South
# 2     2017     10       AL  Alabama                196250  South
# 3     2017     11       AL  Alabama                195000  South
# 4     2017     12       AL  Alabama                194900  South
# ...    ...    ...      ...      ...                   ...    ...
# 4891  2025      3       WY  Wyoming                459900   West
# 4892  2025      4       WY  Wyoming                476000   West
# 4893  2025      5       WY  Wyoming                495000   West
# 4894  2025      6       WY  Wyoming                496741   West
# 4895  2025      7       WY  Wyoming                496647   West
#
#                 Division  median_listing_price_prev  \
# 0     East South Central                   198060.0
# 1     East South Central                   197116.0
# 2     East South Central                   198000.0
# 3     East South Central                   196250.0
# 4     East South Central                   195000.0
# ...                  ...                        ...
# 4891            Mountain                   459725.0
# 4892            Mountain                   459900.0
# 4893            Mountain                   476000.0
# 4894            Mountain                   495000.0
# 4895            Mountain                   496741.0
#
#       median_listing_price_mm_prev  median_listing_price_yy_prev  \
# 0                        -0.004223                        0.0654
# 1                        -0.004766                        0.0655
# 2                         0.004485                        0.0708
# 3                        -0.008838                        0.0736
# 4                        -0.006369                        0.0803
# ...                            ...                           ...
# 4891                     -0.000435                        0.0229
# 4892                      0.000381                        0.0243
# 4893                      0.035008                        0.0462
# 4894                      0.039916                        0.0623
# 4895                      0.003517                        0.0458
#
#       active_listing_count_prev  active_listing_count_mm_prev  \
# 0                       26519.0                      0.002343
# 1                       26367.0                     -0.005732
# 2                       26102.0                     -0.010050
# 3                       25586.0                     -0.019769
# 4                       24859.0                     -0.028414
# ...                         ...                           ...
# 4891                     1834.0                     -0.041797
# 4892                     1826.0                     -0.004362
# 4893                     1945.0                      0.065170
# 4894                     2208.0                      0.135219
# 4895                     2519.0                      0.140851
#
#       active_listing_count_yy_prev  median_days_on_market_prev  \
# 0                          -0.1296                        75.0
# 1                          -0.1189                        77.0
# 2                          -0.1169                        79.0
# 3                          -0.1154                        83.0
# 4                          -0.1098                        88.0
# ...                            ...                         ...
# 4891                        0.0956                        88.0
# 4892                        0.1127                        68.0
# 4893                        0.1421                        57.0
# 4894                        0.1820                        51.0
# 4895                        0.1644                        50.0
#
#       median_days_on_market_mm_prev  median_days_on_market_yy_prev  \
# 0                          0.027397                        -0.0385
# 1                          0.026667                        -0.0667
# 2                          0.025974                        -0.0706
# 3                          0.050633                        -0.0625
# 4                          0.060241                        -0.0591
# ...                             ...                            ...
# 4891                      -0.011236                        -0.0112
# 4892                      -0.227273                        -0.0556
# 4893                      -0.161765                        -0.1172
# 4894                      -0.105263                         0.0000
# 4895                      -0.019608                         0.0638
#
#       new_listing_count_prev  new_listing_count_mm_prev  \
# 0                     7772.0                   0.019680
# 1                     7198.0                  -0.073855
# 2                     6364.0                  -0.115866
# 3                     6190.0                  -0.027341
# 4                     5790.0                  -0.064620
# ...                      ...                        ...
# 4891                   594.0                   0.060714
# 4892                   784.0                   0.319865
# 4893                   942.0                   0.201531
# 4894                  1028.0                   0.091295
# 4895                  1146.0                   0.114786
#
#       new_listing_count_yy_prev  price_increased_count_prev  \
# 0                        0.0021                       552.0
# 1                        0.0456                       478.0
# 2                       -0.0467                       436.0
# 3                        0.0154                       514.0
# 4                        0.0859                       548.0
# ...                         ...                         ...
# 4891                     0.0919                         0.0
# 4892                     0.1951                        12.0
# 4893                     0.1135                        16.0
# 4894                     0.1762                        12.0
# 4895                     0.1506                        14.0
#
#       price_increased_count_mm_prev  price_increased_count_yy_prev  \
# 0                         -0.073826                         0.5000
# 1                         -0.134058                         0.0575
# 2                         -0.087866                         0.0283
# 3                          0.178899                        -0.0115
# 4                          0.066148                         0.4271
# ...                             ...                            ...
# 4891                      -1.000000                        -1.0000
# 4892                      12.000000                        -0.2500
# 4893                       0.333333                        -0.2000
# 4894                      -0.250000                         0.0000
# 4895                       0.166667                         0.7500
#
#       price_increased_share_prev  price_increased_share_mm_prev  \
# 0                         0.0155                      -0.043210
# 1                         0.0135                      -0.129032
# 2                         0.0128                      -0.051852
# 3                         0.0154                       0.203125
# 4                         0.0169                       0.097403
# ...                          ...                            ...
# 4891                      0.0000                      -1.000000
# 4892                      0.0041                       0.004100
# 4893                      0.0046                       0.121951
# 4894                      0.0033                      -0.282609
# 4895                      0.0032                      -0.030303
#
#       price_increased_share_yy_prev  price_reduced_count_prev  \
# 0                            0.0061                    6064.0
# 1                            0.0018                    5938.0
# 2                            0.0017                    5564.0
# 3                            0.0011                    4886.0
# 4                            0.0067                    4416.0
# ...                             ...                       ...
# 4891                        -0.0045                     304.0
# 4892                        -0.0018                     332.0
# 4893                        -0.0019                     388.0
# 4894                        -0.0004                     520.0
# 4895                         0.0011                     682.0
#
#       price_reduced_count_mm_prev  price_reduced_count_yy_prev  \
# 0                        0.024670                      -0.0111
# 1                       -0.020778                       0.0126
# 2                       -0.062984                      -0.0390
# 3                       -0.121855                      -0.0725
# 4                       -0.096193                       0.1191
# ...                           ...                          ...
# 4891                     0.020134                       0.2459
# 4892                     0.092105                       0.4310
# 4893                     0.168675                       0.2357
# 4894                     0.340206                       0.3000
# 4895                     0.311538                       0.2724
#
#       price_reduced_share_prev  price_reduced_share_mm_prev  \
# 0                       0.1704                     0.055108
# 1                       0.1660                    -0.025822
# 2                       0.1633                    -0.016265
# 3                       0.1469                    -0.100429
# 4                       0.1365                    -0.070796
# ...                        ...                          ...
# 4891                    0.1096                     0.047801
# 4892                    0.1058                    -0.034672
# 4893                    0.1135                     0.072779
# 4894                    0.1354                     0.192952
# 4895                    0.1597                     0.179468
#
#       price_reduced_share_yy_prev  pending_listing_count_prev  \
# 0                          0.0151                      2092.0
# 1                          0.0134                      1965.0
# 2                          0.0104                      1719.0
# 3                          0.0021                      1668.0
# 4                          0.0303                      1669.0
# ...                           ...                         ...
# 4891                       0.0180                       435.0
# 4892                       0.0271                       502.0
# 4893                       0.0121                       597.0
# 4894                       0.0166                       615.0
# 4895                       0.0161                       649.0
#
#       pending_listing_count_mm_prev  pending_listing_count_yy_prev  \
# 0                         -0.066071                         0.1265
# 1                         -0.060707                         0.0318
# 2                         -0.125191                        -0.0095
# 3                         -0.029668                         0.0312
# 4                          0.000600                         0.1498
# ...                             ...                            ...
# 4891                       0.172507                        -0.0492
# 4892                       0.154023                        -0.0652
# 4893                       0.189243                         0.0093
# 4894                       0.030151                        -0.0144
# 4895                       0.055285                         0.0973
#
#       median_listing_price_per_square_foot_prev  \
# 0                                          95.0
# 1                                          95.0
# 2                                          96.0
# 3                                          96.0
# 4                                          96.0
# ...                                         ...
# 4891                                      209.0
# 4892                                      208.0
# 4893                                      209.0
# 4894                                      211.0
# 4895                                      217.0
#
#       median_listing_price_per_square_foot_mm_prev  \
# 0                                         0.000000
# 1                                         0.000000
# 2                                         0.010526
# 3                                         0.000000
# 4                                         0.000000
# ...                                            ...
# 4891                                      0.019512
# 4892                                     -0.004785
# 4893                                      0.004808
# 4894                                      0.009569
# 4895                                      0.028436
#
#       median_listing_price_per_square_foot_yy_prev  median_square_feet_prev  \
# 0                                           0.0378                   2022.0
# 1                                           0.0379                   2008.0
# 2                                           0.0455                   2000.0
# 3                                           0.0467                   2000.0
# 4                                           0.0467                   2000.0
# ...                                            ...                      ...
# 4891                                        0.1043                   2171.0
# 4892                                        0.0800                   2176.0
# 4893                                        0.0716                   2204.0
# 4894                                        0.0443                   2216.0
# 4895                                        0.0210                   2209.0
#
#       median_square_feet_mm_prev  median_square_feet_yy_prev  \
# 0                       0.000495                      0.0233
# 1                      -0.006924                      0.0170
# 2                      -0.003984                      0.0209
# 3                       0.000000                      0.0256
# 4                       0.000000                      0.0262
# ...                          ...                         ...
# 4891                   -0.014973                     -0.0418
# 4892                    0.002303                     -0.0357
# 4893                    0.012868                     -0.0267
# 4894                    0.005445                     -0.0353
# 4895                   -0.003159                     -0.0222
#
#       average_listing_price_prev  average_listing_price_mm_prev  \
# 0                       264342.0                      -0.000707
# 1                       263188.0                      -0.004366
# 2                       264218.0                       0.003914
# 3                       264749.0                       0.002010
# 4                       267844.0                       0.011690
# ...                          ...                            ...
# 4891                   1198147.0                       0.026985
# 4892                   1166754.0                      -0.026201
# 4893                   1108065.0                      -0.050301
# 4894                   1064091.0                      -0.039685
# 4895                   1166952.0                       0.096666
#
#       average_listing_price_yy_prev  total_listing_count_prev  \
# 0                            0.0543                   28563.0
# 1                            0.0500                   28314.0
# 2                            0.0635                   27851.0
# 3                            0.0578                   27241.0
# 4                            0.0833                   26511.0
# ...                             ...                       ...
# 4891                         0.2415                    2252.0
# 4892                         0.2582                    2318.0
# 4893                         0.2097                    2535.0
# 4894                         0.1772                    2816.0
# 4895                         0.1760                    3156.0
#
#       total_listing_count_mm_prev  total_listing_count_yy_prev  \
# 0                       -0.004288                      -0.1169
# 1                       -0.008718                      -0.1101
# 2                       -0.016352                      -0.1095
# 3                       -0.021902                      -0.1076
# 4                       -0.026798                      -0.0973
# ...                           ...                          ...
# 4891                    -0.013146                       0.0628
# 4892                     0.029307                       0.0657
# 4893                     0.093615                       0.1128
# 4894                     0.110848                       0.1373
# 4895                     0.120739                       0.1529
#
#       pending_ratio_prev  pending_ratio_mm_prev  pending_ratio_yy_prev
# 0                 0.0789              -0.067376                 0.0179
# 1                 0.0745              -0.055767                 0.0109
# 2                 0.0659              -0.115436                 0.0071
# 3                 0.0652              -0.010622                 0.0093
# 4                 0.0671               0.029141                 0.0152
# ...                  ...                    ...                    ...
# 4891              0.2370               0.224174                -0.0361
# 4892              0.2749               0.159916                -0.0523
# 4893              0.3067               0.115678                -0.0404
# 4894              0.2785              -0.091947                -0.0555
# 4895              0.2575              -0.075404                -0.0157
#
# [4896 rows x 49 columns]

# %%
input_df
# Out:
#     year  month state_id                 state  median_listing_price_prev  \
# 0   2025      8       AL               Alabama                     339650
# 1   2025      8       AK                Alaska                     445450
# 2   2025      8       AZ               Arizona                     487450
# 3   2025      8       AR              Arkansas                     305000
# 4   2025      8       CA            California                     750000
# 5   2025      8       CO              Colorado                     599000
# 6   2025      8       CT           Connecticut                     549900
# 7   2025      8       DE              Delaware                     485000
# 8   2025      8       DC  District of Columbia                     597999
# 9   2025      8       FL               Florida                     435000
# 10  2025      8       GA               Georgia                     399250
# 11  2025      8       HI                Hawaii                     761000
# 12  2025      8       ID                 Idaho                     599450
# 13  2025      8       IL              Illinois                     323225
# 14  2025      8       IN               Indiana                     309450
# 15  2025      8       IA                  Iowa                     289938
# 16  2025      8       KS                Kansas                     301126
# 17  2025      8       KY              Kentucky                     315000
# 18  2025      8       LA             Louisiana                     284950
# 19  2025      8       ME                 Maine                     485000
# 20  2025      8       MD              Maryland                     450000
# 21  2025      8       MA         Massachusetts                     797000
# 22  2025      8       MI              Michigan                     316950
# 23  2025      8       MN             Minnesota                     399000
# 24  2025      8       MS           Mississippi                     299000
# 25  2025      8       MO              Missouri                     311000
# 26  2025      8       MT               Montana                     649900
# 27  2025      8       NE              Nebraska                     349985
# 28  2025      8       NV                Nevada                     499450
# 29  2025      8       NH         New Hampshire                     599000
# 30  2025      8       NJ            New Jersey                     577500
# 31  2025      8       NM            New Mexico                     411000
# 32  2025      8       NY              New York                     671500
# 33  2025      8       NC        North Carolina                     424950
# 34  2025      8       ND          North Dakota                     369950
# 35  2025      8       OH                  Ohio                     289950
# 36  2025      8       OK              Oklahoma                     304995
# 37  2025      8       OR                Oregon                     577000
# 38  2025      8       PA          Pennsylvania                     324995
# 39  2025      8       RI          Rhode Island                     599450
# 40  2025      8       SC        South Carolina                     371950
# 41  2025      8       SD          South Dakota                     389900
# 42  2025      8       TN             Tennessee                     439950
# 43  2025      8       TX                 Texas                     375000
# 44  2025      8       UT                  Utah                     599450
# 45  2025      8       VT               Vermont                     525000
# 46  2025      8       VA              Virginia                     461973
# 47  2025      8       WA            Washington                     659475
# 48  2025      8       WV         West Virginia                     270000
# 49  2025      8       WI             Wisconsin                     399900
# 50  2025      8       WY               Wyoming                     496647
#
#     median_listing_price_mm_prev  median_listing_price_yy_prev  \
# 0                      -0.001029                        0.0142
# 1                      -0.007906                        0.0361
# 2                      -0.020201                       -0.0239
# 3                       0.000000                        0.0224
# 4                      -0.027868                       -0.0347
# 5                      -0.001583                       -0.0362
# 6                      -0.021051                        0.0337
# 7                      -0.020202                       -0.0332
# 8                      -0.003169                       -0.0024
# 9                      -0.009112                       -0.0312
# 10                     -0.001625                       -0.0016
# 11                     -0.007693                       -0.0788
# 12                      0.000751                        0.0425
# 13                     -0.005462                       -0.0350
# 14                     -0.001774                        0.0315
# 15                     -0.017159                       -0.0332
# 16                     -0.020728                       -0.0207
# 17                      0.000000                        0.0112
# 18                     -0.000175                        0.0179
# 19                     -0.015228                        0.0778
# 20                     -0.010880                        0.0346
# 21                     -0.003065                       -0.0031
# 22                     -0.000158                        0.0565
# 23                     -0.002375                       -0.0024
# 24                      0.000854                        0.0000
# 25                      0.000016                        0.0134
# 26                      0.000000                       -0.0175
# 27                     -0.016249                       -0.0113
# 28                     -0.000900                       -0.0071
# 29                      0.000000                        0.0373
# 30                     -0.003365                       -0.0210
# 31                      0.002322                        0.0314
# 32                     -0.030255                        0.0000
# 33                     -0.000118                        0.0119
# 34                      0.003200                       -0.0135
# 35                     -0.017119                        0.0359
# 36                     -0.011041                        0.0168
# 37                     -0.005172                        0.0000
# 38                     -0.012173                        0.0001
# 39                      0.000751                        0.0160
# 40                     -0.007869                        0.0335
# 41                     -0.012911                       -0.0228
# 42                     -0.000114                        0.0062
# 43                     -0.007937                       -0.0130
# 44                     -0.000833                       -0.0133
# 45                      0.002387                        0.0000
# 46                     -0.025197                        0.0300
# 47                     -0.022638                        0.0076
# 48                     -0.018182                        0.1192
# 49                      0.000000                        0.0127
# 50                     -0.000189                        0.0137
#
#     active_listing_count_prev  active_listing_count_mm_prev  \
# 0                       20698                      0.019706
# 1                        1970                      0.088999
# 2                       29089                     -0.043156
# 3                       12652                      0.023956
# 4                       77994                      0.016381
# 5                       32276                      0.039887
# 6                        5120                      0.050903
# 7                        3012                     -0.011487
# 8                        2844                     -0.065396
# 9                      174584                     -0.022683
# 10                      48667                      0.026102
# 11                       6404                     -0.008976
# 12                       9452                      0.041313
# 13                      20843                      0.060712
# 14                      15560                      0.062189
# 15                      10818                      0.036207
# 16                       7619                      0.032805
# 17                      11247                      0.051810
# 18                      16784                      0.007624
# 19                       5089                      0.081156
# 20                      13995                      0.005532
# 21                      11283                     -0.034072
# 22                      23073                      0.064990
# 23                      14196                      0.040305
# 24                       8521                      0.015009
# 25                      19195                      0.030272
# 26                       6116                      0.059598
# 27                       5291                      0.049177
# 28                      13097                      0.026411
# 29                       3189                      0.071573
# 30                      17584                      0.020664
# 31                       6770                      0.027938
# 32                      38489                      0.016211
# 33                      42574                      0.024818
# 34                       2100                      0.032956
# 35                      20138                      0.086368
# 36                      15441                      0.036170
# 37                      16850                      0.043473
# 38                      23901                      0.027381
# 39                       1615                      0.018285
# 40                      25999                      0.017773
# 41                       3373                      0.059027
# 42                      33046                      0.029759
# 43                     140980                      0.019710
# 44                      14238                      0.026088
# 45                       2383                      0.137470
# 46                      20709                      0.021506
# 47                      24224                      0.062503
# 48                       3808                      0.036473
# 49                      12314                      0.040034
# 50                       2771                      0.100040
#
#     active_listing_count_yy_prev  median_days_on_market_prev  \
# 0                         0.1912                          66
# 1                         0.0407                          51
# 2                         0.3630                          69
# 3                         0.2615                          61
# 4                         0.3648                          52
# 5                         0.3597                          56
# 6                         0.1429                          39
# 7                         0.2643                          57
# 8                         0.2107                          58
# 9                         0.2353                          86
# 10                        0.3013                          58
# 11                        0.2776                          83
# 12                        0.1522                          55
# 13                        0.0767                          37
# 14                        0.2241                          45
# 15                        0.2264                          54
# 16                        0.2387                          51
# 17                        0.2662                          51
# 18                        0.0785                          73
# 19                        0.2391                          53
# 20                        0.4816                          39
# 21                        0.2627                          43
# 22                        0.1815                          42
# 23                        0.1513                          44
# 24                        0.0931                          71
# 25                        0.2326                          52
# 26                        0.1494                          59
# 27                        0.1820                          45
# 28                        0.5295                          54
# 29                        0.2662                          43
# 30                        0.1989                          39
# 31                        0.3088                          66
# 32                        0.0948                          59
# 33                        0.4073                          59
# 34                        0.0682                          54
# 35                        0.2149                          39
# 36                        0.2027                          58
# 37                        0.2228                          60
# 38                        0.1349                          47
# 39                        0.2500                          37
# 40                        0.2470                          61
# 41                        0.3596                          51
# 42                        0.2874                          60
# 43                        0.2408                          60
# 44                        0.2890                          61
# 45                        0.3041                          49
# 46                        0.3441                          43
# 47                        0.3158                          45
# 48                        0.1582                          53
# 49                        0.1394                          39
# 50                        0.1916                          52
#
#     median_days_on_market_mm_prev  median_days_on_market_yy_prev  \
# 0                        0.047619                         0.1391
# 1                        0.085106                         0.0737
# 2                        0.078125                         0.2212
# 3                        0.033898                         0.0702
# 4                        0.083333                         0.1705
# 5                        0.142857                         0.2472
# 6                        0.147059                         0.0541
# 7                        0.140000                         0.0962
# 8                        0.137255                         0.1262
# 9                        0.075000                         0.2128
# 10                       0.054545                         0.2340
# 11                       0.064103                         0.2296
# 12                       0.195652                         0.0900
# 13                       0.000000                         0.0278
# 14                       0.046512                         0.1111
# 15                       0.038462                         0.0094
# 16                       0.040816                         0.0521
# 17                       0.020000                         0.1087
# 18                       0.028169                         0.0735
# 19                       0.127660                         0.1290
# 20                       0.083333                         0.0263
# 21                       0.264706                         0.1184
# 22                       0.135135                         0.0641
# 23                       0.128205                         0.1139
# 24                       0.044118                         0.0763
# 25                       0.040000                         0.0300
# 26                       0.113208                         0.0631
# 27                       0.046512                         0.0345
# 28                       0.058824                         0.2442
# 29                       0.162162                         0.1622
# 30                       0.054054                         0.0405
# 31                       0.031250                         0.1478
# 32                       0.113208                         0.0174
# 33                       0.092593                         0.1700
# 34                       0.125000                         0.0490
# 35                       0.054054                         0.0694
# 36                       0.054545                         0.0849
# 37                       0.111111                         0.1765
# 38                       0.044444                         0.0444
# 39                       0.156250                         0.1045
# 40                       0.051724                         0.1091
# 41                       0.108696                         0.1087
# 42                       0.052632                         0.3187
# 43                       0.071429                         0.0917
# 44                       0.089286                         0.1635
# 45                       0.065217                         0.0538
# 46                       0.102564                         0.1316
# 47                       0.125000                         0.1392
# 48                       0.104167                        -0.0187
# 49                       0.054054                         0.0405
# 50                       0.040000                         0.0097
#
#     new_listing_count_prev  new_listing_count_mm_prev  \
# 0                     7082                  -0.074974
# 1                      990                  -0.076493
# 2                     8858                  -0.103441
# 3                     4352                  -0.066895
# 4                    31892                  -0.082561
# 5                     9836                  -0.199675
# 6                     3694                  -0.109450
# 7                     1400                  -0.001427
# 8                      850                  -0.155070
# 9                    38240                  -0.071304
# 10                   15758                  -0.078372
# 11                    1470                  -0.245380
# 12                    3492                  -0.109184
# 13                   14352                  -0.030925
# 14                    9098                  -0.025701
# 15                    4508                   0.000888
# 16                    3904                  -0.016625
# 17                    5572                   0.022010
# 18                    4478                  -0.036160
# 19                    2422                  -0.068462
# 20                    7236                  -0.109086
# 21                    6608                  -0.203855
# 22                   14280                  -0.018422
# 23                    8270                  -0.070160
# 24                    2796                  -0.035862
# 25                    8962                  -0.071872
# 26                    1748                  -0.190741
# 27                    2660                   0.031808
# 28                    4406                  -0.061355
# 29                    1986                  -0.112601
# 30                    9890                  -0.011395
# 31                    2280                  -0.139623
# 32                   15490                  -0.178249
# 33                   16472                  -0.052135
# 34                     862                  -0.069114
# 35                   14814                  -0.010289
# 36                    5884                  -0.015395
# 37                    5604                  -0.110194
# 38                   14228                   0.006223
# 39                    1026                  -0.112457
# 40                    9508                  -0.041725
# 41                    1136                  -0.080906
# 42                   11922                  -0.058889
# 43                   40154                  -0.092770
# 44                    4700                  -0.108498
# 45                    1028                  -0.063752
# 46                   10752                  -0.094187
# 47                   10460                  -0.094999
# 48                    1900                  -0.003148
# 49                    6928                  -0.040709
# 50                    1004                  -0.123909
#
#     new_listing_count_yy_prev  price_increased_count_prev  \
# 0                      0.0025                         358
# 1                     -0.0748                          20
# 2                      0.0298                         648
# 3                     -0.0355                         120
# 4                      0.0177                        1326
# 5                     -0.0281                         292
# 6                      0.0330                          46
# 7                      0.1041                         100
# 8                      0.0341                          26
# 9                     -0.0481                        2160
# 10                     0.0187                         876
# 11                    -0.1069                          48
# 12                     0.0259                         122
# 13                     0.0447                         214
# 14                     0.0482                         212
# 15                     0.1801                          56
# 16                     0.0495                         120
# 17                     0.0853                         120
# 18                    -0.0071                         162
# 19                     0.0793                          24
# 20                     0.0361                         372
# 21                     0.0731                          78
# 22                     0.0503                         264
# 23                    -0.0043                         230
# 24                     0.0488                          78
# 25                     0.0217                         236
# 26                    -0.0023                          22
# 27                     0.1310                         126
# 28                     0.0367                         188
# 29                     0.0365                          40
# 30                     0.0501                         280
# 31                    -0.0902                          72
# 32                     0.0785                         436
# 33                     0.1471                         804
# 34                    -0.0315                          22
# 35                     0.0494                         190
# 36                    -0.0137                         246
# 37                    -0.0453                        1038
# 38                     0.0615                         380
# 39                    -0.0757                          14
# 40                     0.0650                         574
# 41                     0.0327                          12
# 42                     0.1132                         508
# 43                     0.0685                        2362
# 44                     0.0271                         392
# 45                     0.0642                          16
# 46                     0.0258                         362
# 47                     0.0400                         442
# 48                     0.1337                          42
# 49                     0.0526                          78
# 50                     0.0681                          14
#
#     price_increased_count_mm_prev  price_increased_count_yy_prev  \
# 0                       -0.037634                        -0.1713
# 1                        0.000000                        -0.4118
# 2                        0.098305                         0.1020
# 3                       -0.076923                         0.1321
# 4                       -0.161820                        -0.1311
# 5                       -0.193370                        -0.1043
# 6                       -0.178571                        -0.1154
# 7                        0.250000                         0.1111
# 8                       -0.350000                         0.1818
# 9                       -0.137380                        -0.2180
# 10                       0.020979                         0.0023
# 11                       0.090909                         0.2632
# 12                      -0.298851                        -0.1159
# 13                       0.070000                         0.1263
# 14                       0.070707                         0.0291
# 15                      -0.333333                        -0.7956
# 16                       0.224490                        -0.1176
# 17                       0.111111                         0.0345
# 18                       0.173913                         0.3500
# 19                       0.200000                         0.0909
# 20                      -0.055838                        -0.0792
# 21                       0.392857                         0.1143
# 22                       0.031250                         0.0313
# 23                       0.474359                         0.3068
# 24                      -0.220000                        -0.3390
# 25                       0.145631                         0.0442
# 26                       0.000000                         0.1000
# 27                       0.852941                         0.3404
# 28                       0.068182                        -0.0600
# 29                      -0.200000                         1.5000
# 30                       0.166667                         0.1667
# 31                      -0.121951                         0.0909
# 32                       0.191257                         0.3212
# 33                       0.012594                         0.2036
# 34                      -0.312500                         0.0000
# 35                      -0.280303                         0.0000
# 36                      -0.016000                         0.5974
# 37                      -0.017045                         0.0157
# 38                      -0.162996                        -0.1775
# 39                       0.166667                         1.3333
# 40                      -0.209366                        -0.2180
# 41                       0.000000                        -0.2500
# 42                      -0.127148                         0.4190
# 43                      -0.096404                         0.0865
# 44                      -0.053140                         0.1395
# 45                       0.000000                         0.3333
# 46                      -0.206140                        -0.2551
# 47                      -0.255892                        -0.0830
# 48                      -0.192308                        -0.4167
# 49                      -0.113636                        -0.1333
# 50                       0.000000                         0.1667
#
#     price_increased_share_prev  price_increased_share_mm_prev  \
# 0                       0.0100                      -0.047619
# 1                       0.0051                       0.020000
# 2                       0.0135                       0.153846
# 3                       0.0057                      -0.050000
# 4                       0.0096                      -0.150442
# 5                       0.0055                      -0.191176
# 6                       0.0033                      -0.108108
# 7                       0.0144                       0.125000
# 8                       0.0059                      -0.262500
# 9                       0.0084                      -0.106383
# 10                      0.0109                       0.028302
# 11                      0.0050                       0.136364
# 12                      0.0071                      -0.303922
# 13                      0.0040                       0.052632
# 14                      0.0062                       0.087719
# 15                      0.0029                      -0.309524
# 16                      0.0076                       0.245902
# 17                      0.0053                       0.127660
# 18                      0.0062                       0.192308
# 19                      0.0027                       0.125000
# 20                      0.0138                       0.086614
# 21                      0.0038                       0.583333
# 22                      0.0051                       0.020000
# 23                      0.0072                       0.500000
# 24                      0.0054                      -0.194030
# 25                      0.0064                       0.185185
# 26                      0.0023                       0.000000
# 27                      0.0113                       0.883333
# 28                      0.0088                       0.073171
# 29                      0.0052                      -0.187500
# 30                      0.0073                       0.216667
# 31                      0.0061                      -0.102941
# 32                      0.0051                       0.214286
# 33                      0.0100                       0.020408
# 34                      0.0052                      -0.324675
# 35                      0.0037                      -0.301887
# 36                      0.0091                      -0.010870
# 37                      0.0358                      -0.037634
# 38                      0.0067                      -0.192771
# 39                      0.0036                       0.333333
# 40                      0.0122                      -0.202614
# 41                      0.0021                       0.000000
# 42                      0.0087                      -0.121212
# 43                      0.0107                      -0.085470
# 44                      0.0164                      -0.023810
# 45                      0.0034                      -0.055556
# 46                      0.0090                      -0.134615
# 47                      0.0097                      -0.270677
# 48                      0.0049                      -0.246154
# 49                      0.0030                      -0.142857
# 50                      0.0033                       0.031250
#
#     price_increased_share_yy_prev  price_reduced_count_prev  \
# 0                         -0.0044                      7174
# 1                         -0.0036                       736
# 2                         -0.0014                     13112
# 3                          0.0002                      4122
# 4                         -0.0033                     26750
# 5                         -0.0019                     14672
# 6                         -0.0004                      1510
# 7                         -0.0021                       980
# 8                          0.0005                       712
# 9                         -0.0036                     57158
# 10                        -0.0020                     20148
# 11                         0.0005                      1356
# 12                        -0.0017                      3950
# 13                         0.0003                      7758
# 14                        -0.0010                      8758
# 15                        -0.0126                      3790
# 16                        -0.0017                      2818
# 17                        -0.0007                      4740
# 18                         0.0013                      5296
# 19                        -0.0003                      1850
# 20                        -0.0029                      5582
# 21                        -0.0008                      3820
# 22                        -0.0007                      9570
# 23                         0.0014                      5836
# 24                        -0.0030                      2784
# 25                        -0.0002                      7250
# 26                         0.0000                      2002
# 27                         0.0016                      1632
# 28                        -0.0030                      5218
# 29                         0.0021                      1162
# 30                         0.0006                      4404
# 31                        -0.0006                      2290
# 32                         0.0006                      8338
# 33                        -0.0001                     18256
# 34                        -0.0002                       586
# 35                        -0.0002                     10418
# 36                         0.0029                      5912
# 37                        -0.0039                      8078
# 38                        -0.0023                      9148
# 39                         0.0021                       462
# 40                        -0.0055                     10698
# 41                        -0.0013                       972
# 42                         0.0011                     14392
# 43                        -0.0007                     55952
# 44                         0.0004                      6052
# 45                        -0.0001                       616
# 46                        -0.0043                      8058
# 47                        -0.0030                     10096
# 48                        -0.0044                      1296
# 49                        -0.0008                      3974
# 50                         0.0001                       792
#
#     price_reduced_count_mm_prev  price_reduced_count_yy_prev  \
# 0                      0.012705                       0.1741
# 1                      0.091988                      -0.0777
# 2                     -0.125750                       0.2728
# 3                      0.038287                       0.2202
# 4                     -0.024719                       0.3759
# 5                     -0.005153                       0.2321
# 6                      0.024423                       0.1778
# 7                     -0.112319                       0.3920
# 8                     -0.222707                       0.1447
# 9                     -0.085911                       0.0876
# 10                     0.038022                       0.3075
# 11                    -0.109067                       0.0447
# 12                     0.075708                       0.2131
# 13                     0.146615                       0.1621
# 14                     0.098595                       0.2526
# 15                     0.059251                       0.0622
# 16                     0.069044                       0.2580
# 17                     0.089655                       0.2487
# 18                    -0.011571                       0.0906
# 19                     0.156250                       0.2187
# 20                     0.035237                       0.4759
# 21                    -0.127057                       0.3841
# 22                     0.140916                       0.2026
# 23                     0.083550                       0.2168
# 24                     0.022026                       0.1048
# 25                     0.000000                       0.1800
# 26                     0.057022                       0.1414
# 27                     0.119342                       0.2496
# 28                    -0.055737                       0.4257
# 29                     0.096226                       0.4171
# 30                     0.027052                       0.3501
# 31                     0.040909                       0.2194
# 32                     0.032953                       0.1817
# 33                     0.021258                       0.3822
# 34                    -0.020067                      -0.0201
# 35                     0.163502                       0.2884
# 36                     0.018257                       0.1151
# 37                     0.040175                       0.2158
# 38                     0.019389                       0.1395
# 39                    -0.041494                       0.2762
# 40                    -0.055614                       0.1692
# 41                     0.012500                       0.4507
# 42                     0.013236                       0.1902
# 43                    -0.020380                       0.2196
# 44                    -0.055850                       0.3730
# 45                     0.026667                       0.2623
# 46                     0.018453                       0.3676
# 47                     0.066103                       0.2607
# 48                     0.055375                       0.1634
# 49                     0.122599                       0.2442
# 50                     0.161290                       0.3113
#
#     price_reduced_share_prev  price_reduced_share_mm_prev  \
# 0                     0.1966                     0.019710
# 1                     0.1805                     0.060517
# 2                     0.2789                    -0.052971
# 3                     0.1894                     0.038947
# 4                     0.1939                    -0.010209
# 5                     0.2841                     0.015368
# 6                     0.1039                     0.040040
# 7                     0.1573                    -0.095977
# 8                     0.1428                    -0.238806
# 9                     0.2246                    -0.053120
# 10                    0.2504                     0.044639
# 11                    0.1430                    -0.072633
# 12                    0.2314                     0.084349
# 13                    0.1478                     0.153786
# 14                    0.2512                     0.082759
# 15                    0.1855                     0.042721
# 16                    0.1725                     0.091772
# 17                    0.2034                     0.068839
# 18                    0.2014                    -0.001982
# 19                    0.2105                     0.108478
# 20                    0.1652                    -0.053295
# 21                    0.1902                    -0.015018
# 22                    0.1841                     0.123246
# 23                    0.1796                     0.087826
# 24                    0.1890                     0.040749
# 25                    0.1903                     0.012773
# 26                    0.2094                     0.057042
# 27                    0.1460                     0.113654
# 28                    0.2441                    -0.050933
# 29                    0.1507                     0.126308
# 30                    0.1063                    -0.014829
# 31                    0.1945                     0.051351
# 32                    0.0989                     0.048780
# 33                    0.2268                     0.023928
# 34                    0.1428                    -0.016529
# 35                    0.2038                     0.136009
# 36                    0.2123                     0.001888
# 37                    0.2838                     0.036523
# 38                    0.1495                    -0.085067
# 39                    0.1107                     0.012809
# 40                    0.2291                    -0.042624
# 41                    0.1649                    -0.023104
# 42                    0.2471                     0.008160
# 43                    0.2536                    -0.010535
# 44                    0.2486                    -0.039413
# 45                    0.1312                    -0.042336
# 46                    0.1701                    -0.050781
# 47                    0.2258                     0.068117
# 48                    0.1535                     0.003924
# 49                    0.1555                     0.117901
# 50                    0.1817                     0.137758
#
#     price_reduced_share_yy_prev  pending_listing_count_prev  \
# 0                       -0.0010                      8177.0
# 1                       -0.0107                      1097.0
# 2                        0.0166                      9472.0
# 3                        0.0141                      4720.0
# 4                        0.0296                     27988.0
# 5                        0.0107                      9502.0
# 6                        0.0141                      5544.0
# 7                        0.0313                      1784.0
# 8                       -0.0141                       798.0
# 9                       -0.0058                     42706.0
# 10                       0.0276                     15655.0
# 11                      -0.0100                      1656.0
# 12                       0.0232                      4120.0
# 13                       0.0189                     17165.0
# 14                       0.0156                     10098.0
# 15                      -0.0173                      5109.0
# 16                       0.0164                      4768.0
# 17                       0.0152                      6440.0
# 18                       0.0057                      5088.0
# 19                       0.0111                      1176.0
# 20                       0.0154                      8393.0
# 21                       0.0296                      2213.0
# 22                       0.0187                     14493.0
# 23                       0.0198                      9340.0
# 24                       0.0090                      3437.0
# 25                       0.0122                      9956.0
# 26                       0.0083                      1651.0
# 27                       0.0198                      3186.0
# 28                       0.0317                      3870.0
# 29                       0.0039                      2527.0
# 30                       0.0175                     12231.0
# 31                       0.0098                      2601.0
# 32                       0.0013                     30752.0
# 33                       0.0254                     21439.0
# 34                      -0.0107                      1135.0
# 35                       0.0389                     16280.0
# 36                       0.0059                      6458.0
# 37                       0.0255                      5940.0
# 38                      -0.0075                     17399.0
# 39                       0.0220                      1540.0
# 40                       0.0111                     11148.0
# 41                       0.0256                      1219.0
# 42                      -0.0093                     13233.0
# 43                       0.0116                     39128.0
# 44                       0.0396                      5431.0
# 45                      -0.0109                      1218.0
# 46                       0.0089                     10802.0
# 47                       0.0221                      9811.0
# 48                       0.0073                      2448.0
# 49                       0.0190                      6152.0
# 50                       0.0266                       625.0
#
#     pending_listing_count_mm_prev  pending_listing_count_yy_prev  \
# 0                        0.021104                         0.2787
# 1                       -0.004537                        -0.0403
# 2                       -0.080388                        -0.0012
# 3                       -0.038892                         0.0201
# 4                       -0.041178                        -0.0465
# 5                       -0.066143                         0.0193
# 6                       -0.065408                        -0.0551
# 7                       -0.046499                        -0.0847
# 8                       -0.093182                         0.0127
# 9                       -0.062437                        -0.0852
# 10                      -0.083806                        -0.0711
# 11                      -0.009569                        -0.0116
# 12                      -0.026925                         0.0281
# 13                      -0.072112                        -0.0336
# 14                      -0.046459                         0.2493
# 15                      -0.056858                         0.0100
# 16                      -0.068022                         0.0663
# 17                      -0.040381                         0.0995
# 18                      -0.050746                         0.0806
# 19                       0.065217                         0.2206
# 20                      -0.067652                        -0.0257
# 21                      -0.094517                         0.0409
# 22                      -0.029660                         0.0144
# 23                      -0.069536                         0.0160
# 24                      -0.064762                        -0.0301
# 25                      -0.089945                        -0.0114
# 26                      -0.051149                         0.0473
# 27                      -0.091272                         0.0046
# 28                      -0.055176                        -0.0894
# 29                      -0.039163                         1.1325
# 30                      -0.053621                        -0.0296
# 31                      -0.021813                         0.1010
# 32                       0.015890                         0.3437
# 33                      -0.032842                         0.0249
# 34                      -0.015611                         0.0993
# 35                      -0.029219                         0.0156
# 36                      -0.018988                         0.0660
# 37                      -0.023669                        -0.0069
# 38                      -0.005715                         0.0545
# 39                      -0.045849                        -0.0801
# 40                      -0.067581                        -0.0824
# 41                      -0.066616                         0.0366
# 42                      -0.038509                         0.2563
# 43                      -0.055130                         0.0228
# 44                      -0.041645                         0.0095
# 45                       0.028716                         0.9016
# 46                      -0.087515                         0.0216
# 47                      -0.064817                        -0.0737
# 48                      -0.043002                        -0.0724
# 49                      -0.020850                         0.0523
# 50                      -0.036980                         0.0056
#
#     median_listing_price_per_square_foot_prev  \
# 0                                         168
# 1                                         253
# 2                                         267
# 3                                         161
# 4                                         465
# 5                                         290
# 6                                         277
# 7                                         234
# 8                                         494
# 9                                         263
# 10                                        191
# 11                                        695
# 12                                        292
# 13                                        187
# ...
# 45                   -0.003953                      0.0064
# 46                   -0.009420                     -0.0027
# 47                   -0.000505                     -0.0055
# 48                   -0.006101                      0.0234
# 49                   -0.003840                     -0.0100
# 50                   -0.003622                     -0.0353
#
#     average_listing_price_prev  average_listing_price_mm_prev  \
# 0                       456484                      -0.009295
# 1                       540136                      -0.005027
# 2                       733539                      -0.040075
# 3                       406603                      -0.006172
# 4                      1420004                      -0.020438
# 5                      1045184                       0.015646
# 6                      1084062                      -0.024200
# 7                       620061                      -0.014152
# 8                       874363                      -0.041411
# 9                       825198                      -0.017522
# 10                      551036                      -0.007337
# 11                     1419263                      -0.005246
# 12                      933421                       0.009492
# 13                      465891                      -0.018207
# 14                      389651                      -0.003914
# 15                      363971                      -0.008923
# 16                      404377                      -0.009831
# 17                      401716                       0.007226
# 18                      377987                      -0.002765
# 19                      705723                       0.007151
# 20                      613434                      -0.006816
# 21                     1418895                      -0.001988
# 22                      458755                      -0.008969
# 23                      545942                      -0.007006
# 24                      363271                      -0.001298
# 25                      407817                      -0.008700
# 26                     1154428                       0.034605
# 27                      426364                      -0.003711
# 28                      842689                      -0.006840
# 29                      818422                      -0.006924
# 30                      857463                      -0.012872
# 31                      596527                       0.004334
# 32                     1389027                      -0.040411
# 33                      604141                      -0.010380
# 34                      441870                       0.003235
# 35                      383286                      -0.011150
# 36                      403252                      -0.007064
# 37                      756406                      -0.009500
# 38                      448392                      -0.026428
# 39                     1049638                       0.000428
# 40                      572756                      -0.006248
# 41                      522385                      -0.011718
# 42                      629900                      -0.002249
# 43                      533922                      -0.009890
# 44                      989338                       0.010912
# 45                      781872                       0.005727
# 46                      643707                      -0.029208
# 47                      911694                      -0.014751
# 48                      340222                      -0.013174
# 49                      513639                       0.000779
# 50                     1220190                       0.045621
#
#     average_listing_price_yy_prev  total_listing_count_prev  \
# 0                          0.0080                     28808
# 1                          0.0699                      3062
# 2                         -0.0367                     38510
# 3                          0.0244                     17218
# 4                         -0.0745                    105815
# 5                         -0.0522                     41610
# 6                         -0.0002                     10652
# 7                         -0.0455                      4795
# 8                         -0.0718                      3652
# 9                         -0.0376                    216999
# 10                        -0.0383                     63545
# 11                        -0.0997                      8020
# 12                         0.0258                     13548
# 13                        -0.0624                     37931
# 14                         0.0160                     25568
# 15                         0.0095                     15788
# 16                         0.0053                     12358
# 17                         0.0188                     17634
# 18                         0.0114                     21815
# 19                         0.0398                      6284
# 20                         0.0036                     22472
# 21                        -0.0381                     13412
# 22                         0.0223                     37421
# 23                         0.0112                     23431
# 24                         0.0032                     11904
# 25                        -0.0036                     29064
# 26                        -0.0165                      7749
# 27                        -0.0062                      8472
# 28                        -0.0688                     16950
# 29                         0.0762                      5690
# 30                        -0.0517                     29536
# 31                         0.0232                      9371
# 32                        -0.0594                     68805
# 33                        -0.0084                     63842
# 34                         0.0441                      3234
# 35                         0.0149                     36218
# 36                        -0.0048                     21853
# 37                        -0.0142                     22717
# 38                        -0.0284                     41258
# 39                         0.0042                      3129
# 40                         0.0299                     37061
# 41                         0.0065                      4582
# 42                        -0.0114                     46143
# 43                        -0.0162                    179734
# 44                        -0.0157                     19663
# 45                        -0.0229                      3600
# 46                        -0.0220                     31583
# 47                         0.0061                     33964
# 48                         0.0399                      6248
# 49                         0.0226                     18386
# 50                         0.1624                      3394
#
#     total_listing_count_mm_prev  total_listing_count_yy_prev  \
# 0                      0.019716                       0.2148
# 1                      0.053320                       0.0076
# 2                     -0.053343                       0.2497
# 3                      0.005783                       0.1854
# 4                      0.000265                       0.2281
# 5                      0.012286                       0.2610
# 6                     -0.017071                       0.0326
# 7                     -0.024415                       0.1151
# 8                     -0.069317                       0.1666
# 9                     -0.030540                       0.1562
# 10                    -0.003669                       0.1863
# 11                    -0.014015                       0.1986
# 12                     0.019183                       0.1142
# 13                    -0.004984                       0.0242
# 14                     0.014040                       0.2315
# 15                     0.006824                       0.1497
# 16                    -0.010251                       0.1652
# 17                     0.013390                       0.1988
# 18                    -0.008229                       0.0768
# 19                     0.081770                       0.2358
# 20                    -0.016500                       0.2506
# 21                    -0.049334                       0.2243
# 22                     0.024728                       0.1097
# 23                    -0.007834                       0.0934
# 24                    -0.013917                       0.0527
# 25                    -0.007648                       0.1396
# 26                     0.031824                       0.1257
# 27                    -0.008311                       0.1117
# 28                     0.007310                       0.3241
# 29                     0.006189                       0.5394
# 30                    -0.014251                       0.0945
# 31                     0.013629                       0.2456
# 32                     0.015377                       0.1899
# 33                     0.005417                       0.2508
# 34                     0.023418                       0.0834
# 35                     0.033117                       0.1131
# 36                     0.018456                       0.1582
# 37                     0.022183                       0.1568
# 38                     0.009815                       0.1009
# 39                    -0.020657                       0.0632
# 40                    -0.007870                       0.1261
# 41                     0.023682                       0.2543
# 42                     0.006149                       0.2751
# 43                     0.001555                       0.1874
# 44                     0.006089                       0.2020
# 45                     0.097896                       0.4529
# 46                    -0.013555                       0.2226
# 47                     0.019787                       0.1736
# 48                     0.003856                       0.0563
# 49                     0.018954                       0.1123
# 50                     0.075412                       0.1586
#
#     pending_ratio_prev  pending_ratio_mm_prev  pending_ratio_yy_prev  \
# 0               0.3951               0.001521                 0.0270
# 1               0.5566              -0.085893                -0.0469
# 2               0.3256              -0.038961                -0.1187
# 3               0.3731              -0.061147                -0.0883
# 4               0.3588              -0.056782                -0.1548
# 5               0.2944              -0.101891                -0.0983
# 6               1.0828              -0.110710                -0.2268
# 7               0.5924              -0.035022                -0.2258
# 8               0.2804              -0.030093                -0.0548
# 9               0.2446              -0.040784                -0.0857
# 10              0.3217              -0.107133                -0.1290
# 11              0.2586              -0.000387                -0.0757
# 12              0.4358              -0.065609                -0.0526
# 13              0.8235              -0.125239                -0.0940
# 14              0.6490              -0.102227                 0.0131
# 15              0.4722              -0.089823                -0.1012
# 16              0.6258              -0.097621                -0.1012
# 17              0.5726              -0.087635                -0.0868
# 18              0.3031              -0.058111                 0.0006
# 19              0.2311              -0.014078                -0.0035
# 20              0.5997              -0.072820                -0.3122
# 21              0.1961              -0.062620                -0.0418
# 22              0.6281              -0.088918                -0.1035
# 23              0.6579              -0.105628                -0.0876
# 24              0.4033              -0.078593                -0.0512
# 25              0.5187              -0.116655                -0.1280
# 26              0.2699              -0.104809                -0.0263
# 27              0.6022              -0.133650                -0.1063
# 28              0.2954              -0.079751                -0.2008
# 29              0.7924              -0.103316                 0.3219
# 30              0.6956              -0.072657                -0.1638
# 31              0.3841              -0.048787                -0.0725
# 32              0.7990              -0.000250                 0.1480
# 33              0.5036              -0.056222                -0.1879
# 34              0.5405              -0.047241                 0.0153
# 35              0.8084              -0.106444                -0.1587
# 36              0.4182              -0.053418                -0.0536
# 37              0.3525              -0.064242                -0.0815
# 38              0.7280              -0.032172                -0.0556
# 39              0.9533              -0.062912                -0.3420
# 40              0.4288              -0.083761                -0.1539
# 41              0.3615              -0.118293                -0.1126
# 42              0.4004              -0.066449                -0.0099
# 43              0.2775              -0.073456                -0.0591
# 44              0.3814              -0.066112                -0.1056
# 45              0.5112              -0.095061                 0.1607
# 46              0.5216              -0.106696                -0.1647
# 47              0.4050              -0.119757                -0.1703
# 48              0.6429              -0.076691                -0.1598
# 49              0.4996              -0.058424                -0.0413
# 50              0.2254              -0.124660                -0.0417
#
#        Region            Division
# 0       South  East South Central
# 1        West             Pacific
# 2        West            Mountain
# 3       South  West South Central
# 4        West             Pacific
# 5        West            Mountain
# 6   Northeast         New England
# 7       South      South Atlantic
# 8       South      South Atlantic
# 9       South      South Atlantic
# 10      South      South Atlantic
# 11       West             Pacific
# 12       West            Mountain
# 13    Midwest  East North Central
# 14    Midwest  East North Central
# 15    Midwest  West North Central
# 16    Midwest  West North Central
# 17      South  East South Central
# 18      South  West South Central
# 19  Northeast         New England
# 20      South      South Atlantic
# 21  Northeast         New England
# 22    Midwest  East North Central
# 23    Midwest  West North Central
# 24      South  East South Central
# 25    Midwest  West North Central
# 26       West            Mountain
# 27    Midwest  West North Central
# 28       West            Mountain
# 29  Northeast         New England
# 30  Northeast     Middle Atlantic
# 31       West            Mountain
# 32  Northeast     Middle Atlantic
# 33      South      South Atlantic
# 34    Midwest  West North Central
# 35    Midwest  East North Central
# 36      South  West South Central
# 37       West             Pacific
# 38  Northeast     Middle Atlantic
# 39  Northeast         New England
# 40      South      South Atlantic
# 41    Midwest  West North Central
# 42      South  East South Central
# 43      South  West South Central
# 44       West            Mountain
# 45  Northeast         New England
# 46      South      South Atlantic
# 47       West             Pacific
# 48      South      South Atlantic
# 49    Midwest  East North Central
# 50       West            Mountain

# %%
df_lagged = df_lagged.sort_values(["state", "year", "month"])

# Create lag features for 6 and 12 months
df_lagged["median_listing_price_lag6"] = (
    df_lagged.groupby("state")["median_listing_price"].shift(6)
)
df_lagged["median_listing_price_lag12"] = (
    df_lagged.groupby("state")["median_listing_price"].shift(12)
)

# %%
input_df = input_df.sort_values(["state", "year", "month"])

df_lagged["median_listing_price_lag5"] = (
    df_lagged.groupby("state")["median_listing_price"].shift(5)
)
df_lagged["median_listing_price_lag11"] = (
    df_lagged.groupby("state")["median_listing_price"].shift(11)
)

# Create lag features for 6 and 12 months in input_df using last values from df_lagged
input_df["median_listing_price_lag6"] = (
    df_lagged.groupby("state")["median_listing_price_lag5"].last().values
)
input_df["median_listing_price_lag12"] = (
    df_lagged.groupby("state")["median_listing_price_lag11"].last().values
)

df_lagged = df_lagged.drop(columns=['median_listing_price_lag5', 'median_listing_price_lag11'])

# %%
df_lagged.fillna(-1, inplace=True)
input_df.fillna(-1, inplace=True)

# %%
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y):
    X = X.copy()
    
    # Convert datetime columns to numeric
    for colname in X.select_dtypes(["datetime64"]):
        X[colname] = X[colname].view(int)  # Convert datetime to timestamp integers
    
    # Factorize categorical columns
    for colname in X.select_dtypes(["object", "category"]):
        X[colname], _ = X[colname].factorize()
    
    # All discrete features should now have integer dtypes
    discrete_features = [pd.api.types.is_integer_dtype(t) for t in X.dtypes]
    
    # Compute mutual information scores
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features, random_state=0)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    
    return mi_scores

def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores")
    plt.show()

# %%
X = df_lagged.copy()
y = X.pop('median_listing_price')

mi_scores = make_mi_scores(X, y)

print(mi_scores)

plt.figure(dpi=100, figsize=(8, 5))
plot_mi_scores(mi_scores)
# Out:
# median_listing_price_prev                       2.905913
# median_listing_price_lag12                      1.674122
# median_listing_price_lag6                       1.640480
# median_listing_price_per_square_foot_prev       1.589626
# average_listing_price_prev                      1.518743
# state_id                                        1.221970
# state                                           1.221970
# median_listing_price_per_square_foot_mm_prev    0.499101
# Division                                        0.449018
# median_square_feet_prev                         0.373458
# pending_listing_count_prev                      0.369494
# total_listing_count_prev                        0.362513
# active_listing_count_prev                       0.303938
# pending_ratio_prev                              0.288492
# Region                                          0.277442
# price_increased_count_prev                      0.248709
# pending_ratio_yy_prev                           0.242889
# new_listing_count_prev                          0.218370
# year                                            0.216833
# average_listing_price_yy_prev                   0.199712
# active_listing_count_yy_prev                    0.191587
# median_listing_price_yy_prev                    0.180816
# median_listing_price_per_square_foot_yy_prev    0.180770
# pending_listing_count_yy_prev                   0.173705
# price_reduced_count_prev                        0.156966
# price_reduced_count_yy_prev                     0.149331
# total_listing_count_yy_prev                     0.142297
# price_increased_share_prev                      0.139023
# median_days_on_market_prev                      0.128111
# median_listing_price_mm_prev                    0.124942
# median_days_on_market_yy_prev                   0.120215
# price_reduced_share_prev                        0.100041
# active_listing_count_mm_prev                    0.099206
# median_square_feet_yy_prev                      0.098815
# price_reduced_share_yy_prev                     0.088274
# total_listing_count_mm_prev                     0.077736
# price_increased_share_yy_prev                   0.074922
# price_increased_count_yy_prev                   0.071248
# median_days_on_market_mm_prev                   0.066598
# average_listing_price_mm_prev                   0.057598
# new_listing_count_yy_prev                       0.048726
# pending_ratio_mm_prev                           0.030317
# price_reduced_count_mm_prev                     0.030280
# pending_listing_count_mm_prev                   0.028699
# price_increased_count_mm_prev                   0.025243
# median_square_feet_mm_prev                      0.022224
# price_increased_share_mm_prev                   0.019077
# new_listing_count_mm_prev                       0.000431
# month                                           0.000000
# price_reduced_share_mm_prev                     0.000000
# Name: MI Scores, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# Columns to encode
encode_cols = ["state", "state_id", "Region", "Division"]
df_lagged2 = df_lagged.copy()
# Initialize encoder
le_dict = {}
for col in encode_cols:
    le = LabelEncoder()
    df_lagged2[col] = le.fit_transform(df_lagged2[col])
    le_dict[col] = le   # store encoders if you need to inverse_transform later

# %%
import seaborn as sns

spearman_matrix = df_lagged2.corr(method="spearman")

mask = np.triu(np.ones_like(spearman_matrix, dtype=bool))

plt.figure(figsize=(30, 26))
sns.heatmap(spearman_matrix, annot=True, fmt=".2f", cmap="coolwarm", mask=mask)
plt.title("Spearman's Rank Correlation Heatmap")
plt.show()

# %%
df_lagged
# Out:
#       year  month state_id    state  median_listing_price Region  \
# 0     2017      8       AL  Alabama                197116  South
# 1     2017      9       AL  Alabama                198000  South
# 2     2017     10       AL  Alabama                196250  South
# 3     2017     11       AL  Alabama                195000  South
# 4     2017     12       AL  Alabama                194900  South
# ...    ...    ...      ...      ...                   ...    ...
# 4891  2025      3       WY  Wyoming                459900   West
# 4892  2025      4       WY  Wyoming                476000   West
# 4893  2025      5       WY  Wyoming                495000   West
# 4894  2025      6       WY  Wyoming                496741   West
# 4895  2025      7       WY  Wyoming                496647   West
#
#                 Division  median_listing_price_prev  \
# 0     East South Central                   198060.0
# 1     East South Central                   197116.0
# 2     East South Central                   198000.0
# 3     East South Central                   196250.0
# 4     East South Central                   195000.0
# ...                  ...                        ...
# 4891            Mountain                   459725.0
# 4892            Mountain                   459900.0
# 4893            Mountain                   476000.0
# 4894            Mountain                   495000.0
# 4895            Mountain                   496741.0
#
#       median_listing_price_mm_prev  median_listing_price_yy_prev  \
# 0                        -0.004223                        0.0654
# 1                        -0.004766                        0.0655
# 2                         0.004485                        0.0708
# 3                        -0.008838                        0.0736
# 4                        -0.006369                        0.0803
# ...                            ...                           ...
# 4891                     -0.000435                        0.0229
# 4892                      0.000381                        0.0243
# 4893                      0.035008                        0.0462
# 4894                      0.039916                        0.0623
# 4895                      0.003517                        0.0458
#
#       active_listing_count_prev  active_listing_count_mm_prev  \
# 0                       26519.0                      0.002343
# 1                       26367.0                     -0.005732
# 2                       26102.0                     -0.010050
# 3                       25586.0                     -0.019769
# 4                       24859.0                     -0.028414
# ...                         ...                           ...
# 4891                     1834.0                     -0.041797
# 4892                     1826.0                     -0.004362
# 4893                     1945.0                      0.065170
# 4894                     2208.0                      0.135219
# 4895                     2519.0                      0.140851
#
#       active_listing_count_yy_prev  median_days_on_market_prev  \
# 0                          -0.1296                        75.0
# 1                          -0.1189                        77.0
# 2                          -0.1169                        79.0
# 3                          -0.1154                        83.0
# 4                          -0.1098                        88.0
# ...                            ...                         ...
# 4891                        0.0956                        88.0
# 4892                        0.1127                        68.0
# 4893                        0.1421                        57.0
# 4894                        0.1820                        51.0
# 4895                        0.1644                        50.0
#
#       median_days_on_market_mm_prev  median_days_on_market_yy_prev  \
# 0                          0.027397                        -0.0385
# 1                          0.026667                        -0.0667
# 2                          0.025974                        -0.0706
# 3                          0.050633                        -0.0625
# 4                          0.060241                        -0.0591
# ...                             ...                            ...
# 4891                      -0.011236                        -0.0112
# 4892                      -0.227273                        -0.0556
# 4893                      -0.161765                        -0.1172
# 4894                      -0.105263                         0.0000
# 4895                      -0.019608                         0.0638
#
#       new_listing_count_prev  new_listing_count_mm_prev  \
# 0                     7772.0                   0.019680
# 1                     7198.0                  -0.073855
# 2                     6364.0                  -0.115866
# 3                     6190.0                  -0.027341
# 4                     5790.0                  -0.064620
# ...                      ...                        ...
# 4891                   594.0                   0.060714
# 4892                   784.0                   0.319865
# 4893                   942.0                   0.201531
# 4894                  1028.0                   0.091295
# 4895                  1146.0                   0.114786
#
#       new_listing_count_yy_prev  price_increased_count_prev  \
# 0                        0.0021                       552.0
# 1                        0.0456                       478.0
# 2                       -0.0467                       436.0
# 3                        0.0154                       514.0
# 4                        0.0859                       548.0
# ...                         ...                         ...
# 4891                     0.0919                         0.0
# 4892                     0.1951                        12.0
# 4893                     0.1135                        16.0
# 4894                     0.1762                        12.0
# 4895                     0.1506                        14.0
#
#       price_increased_count_mm_prev  price_increased_count_yy_prev  \
# 0                         -0.073826                         0.5000
# 1                         -0.134058                         0.0575
# 2                         -0.087866                         0.0283
# 3                          0.178899                        -0.0115
# 4                          0.066148                         0.4271
# ...                             ...                            ...
# 4891                      -1.000000                        -1.0000
# 4892                      12.000000                        -0.2500
# 4893                       0.333333                        -0.2000
# 4894                      -0.250000                         0.0000
# 4895                       0.166667                         0.7500
#
#       price_increased_share_prev  price_increased_share_mm_prev  \
# 0                         0.0155                      -0.043210
# 1                         0.0135                      -0.129032
# 2                         0.0128                      -0.051852
# 3                         0.0154                       0.203125
# 4                         0.0169                       0.097403
# ...                          ...                            ...
# 4891                      0.0000                      -1.000000
# 4892                      0.0041                       0.004100
# 4893                      0.0046                       0.121951
# 4894                      0.0033                      -0.282609
# 4895                      0.0032                      -0.030303
#
#       price_increased_share_yy_prev  price_reduced_count_prev  \
# 0                            0.0061                    6064.0
# 1                            0.0018                    5938.0
# 2                            0.0017                    5564.0
# 3                            0.0011                    4886.0
# 4                            0.0067                    4416.0
# ...                             ...                       ...
# 4891                        -0.0045                     304.0
# 4892                        -0.0018                     332.0
# 4893                        -0.0019                     388.0
# 4894                        -0.0004                     520.0
# 4895                         0.0011                     682.0
#
#       price_reduced_count_mm_prev  price_reduced_count_yy_prev  \
# 0                        0.024670                      -0.0111
# 1                       -0.020778                       0.0126
# 2                       -0.062984                      -0.0390
# 3                       -0.121855                      -0.0725
# 4                       -0.096193                       0.1191
# ...                           ...                          ...
# 4891                     0.020134                       0.2459
# 4892                     0.092105                       0.4310
# 4893                     0.168675                       0.2357
# 4894                     0.340206                       0.3000
# 4895                     0.311538                       0.2724
#
#       price_reduced_share_prev  price_reduced_share_mm_prev  \
# 0                       0.1704                     0.055108
# 1                       0.1660                    -0.025822
# 2                       0.1633                    -0.016265
# 3                       0.1469                    -0.100429
# 4                       0.1365                    -0.070796
# ...                        ...                          ...
# 4891                    0.1096                     0.047801
# 4892                    0.1058                    -0.034672
# 4893                    0.1135                     0.072779
# 4894                    0.1354                     0.192952
# 4895                    0.1597                     0.179468
#
#       price_reduced_share_yy_prev  pending_listing_count_prev  \
# 0                          0.0151                      2092.0
# 1                          0.0134                      1965.0
# 2                          0.0104                      1719.0
# 3                          0.0021                      1668.0
# 4                          0.0303                      1669.0
# ...                           ...                         ...
# 4891                       0.0180                       435.0
# 4892                       0.0271                       502.0
# 4893                       0.0121                       597.0
# 4894                       0.0166                       615.0
# 4895                       0.0161                       649.0
#
#       pending_listing_count_mm_prev  pending_listing_count_yy_prev  \
# 0                         -0.066071                         0.1265
# 1                         -0.060707                         0.0318
# 2                         -0.125191                        -0.0095
# 3                         -0.029668                         0.0312
# 4                          0.000600                         0.1498
# ...                             ...                            ...
# 4891                       0.172507                        -0.0492
# 4892                       0.154023                        -0.0652
# 4893                       0.189243                         0.0093
# 4894                       0.030151                        -0.0144
# 4895                       0.055285                         0.0973
#
#       median_listing_price_per_square_foot_prev  \
# 0                                          95.0
# 1                                          95.0
# 2                                          96.0
# 3                                          96.0
# 4                                          96.0
# ...                                         ...
# 4891                                      209.0
# 4892                                      208.0
# 4893                                      209.0
# 4894                                      211.0
# 4895                                      217.0
#
#       median_listing_price_per_square_foot_mm_prev  \
# 0                                         0.000000
# 1                                         0.000000
# 2                                         0.010526
# 3                                         0.000000
# 4                                         0.000000
# ...                                            ...
# 4891                                      0.019512
# 4892                                     -0.004785
# 4893                                      0.004808
# 4894                                      0.009569
# 4895                                      0.028436
#
#       median_listing_price_per_square_foot_yy_prev  median_square_feet_prev  \
# 0                                           0.0378                   2022.0
# 1                                           0.0379                   2008.0
# 2                                           0.0455                   2000.0
# 3                                           0.0467                   2000.0
# 4                                           0.0467                   2000.0
# ...                                            ...                      ...
# 4891                                        0.1043                   2171.0
# 4892                                        0.0800                   2176.0
# 4893                                        0.0716                   2204.0
# 4894                                        0.0443                   2216.0
# 4895                                        0.0210                   2209.0
#
#       median_square_feet_mm_prev  median_square_feet_yy_prev  \
# 0                       0.000495                      0.0233
# 1                      -0.006924                      0.0170
# 2                      -0.003984                      0.0209
# 3                       0.000000                      0.0256
# 4                       0.000000                      0.0262
# ...                          ...                         ...
# 4891                   -0.014973                     -0.0418
# 4892                    0.002303                     -0.0357
# 4893                    0.012868                     -0.0267
# 4894                    0.005445                     -0.0353
# 4895                   -0.003159                     -0.0222
#
#       average_listing_price_prev  average_listing_price_mm_prev  \
# 0                       264342.0                      -0.000707
# 1                       263188.0                      -0.004366
# 2                       264218.0                       0.003914
# 3                       264749.0                       0.002010
# 4                       267844.0                       0.011690
# ...                          ...                            ...
# 4891                   1198147.0                       0.026985
# 4892                   1166754.0                      -0.026201
# 4893                   1108065.0                      -0.050301
# 4894                   1064091.0                      -0.039685
# 4895                   1166952.0                       0.096666
#
#       average_listing_price_yy_prev  total_listing_count_prev  \
# 0                            0.0543                   28563.0
# 1                            0.0500                   28314.0
# 2                            0.0635                   27851.0
# 3                            0.0578                   27241.0
# 4                            0.0833                   26511.0
# ...                             ...                       ...
# 4891                         0.2415                    2252.0
# 4892                         0.2582                    2318.0
# 4893                         0.2097                    2535.0
# 4894                         0.1772                    2816.0
# 4895                         0.1760                    3156.0
#
#       total_listing_count_mm_prev  total_listing_count_yy_prev  \
# 0                       -0.004288                      -0.1169
# 1                       -0.008718                      -0.1101
# 2                       -0.016352                      -0.1095
# 3                       -0.021902                      -0.1076
# 4                       -0.026798                      -0.0973
# ...                           ...                          ...
# 4891                    -0.013146                       0.0628
# 4892                     0.029307                       0.0657
# 4893                     0.093615                       0.1128
# 4894                     0.110848                       0.1373
# 4895                     0.120739                       0.1529
#
#       pending_ratio_prev  pending_ratio_mm_prev  pending_ratio_yy_prev  \
# 0                 0.0789              -0.067376                 0.0179
# 1                 0.0745              -0.055767                 0.0109
# 2                 0.0659              -0.115436                 0.0071
# 3                 0.0652              -0.010622                 0.0093
# 4                 0.0671               0.029141                 0.0152
# ...                  ...                    ...                    ...
# 4891              0.2370               0.224174                -0.0361
# 4892              0.2749               0.159916                -0.0523
# 4893              0.3067               0.115678                -0.0404
# 4894              0.2785              -0.091947                -0.0555
# 4895              0.2575              -0.075404                -0.0157
#
#       median_listing_price_lag6  median_listing_price_lag12
# 0                          -1.0                        -1.0
# 1                          -1.0                        -1.0
# 2                          -1.0                        -1.0
# 3                          -1.0                        -1.0
# 4                          -1.0                        -1.0
# ...                         ...                         ...
# 4891                   479750.0                    449000.0
# 4892                   479225.0                    455000.0
# 4893                   460000.0                    465975.0
# 4894                   460000.0                    475000.0
# 4895                   459925.0                    489950.0
#
# [4896 rows x 51 columns]

# %%
df_lagged.to_csv("data/State_lagged.csv", index=False)
